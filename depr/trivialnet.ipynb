# %% [markdown]
# ___
# # **Starter code for BME 5710 project**
# ## Instructor -- Rizwan Ahmad (ahmad.46@osu.edu)
# ## BME5710 -- Spring 2025

# %% [markdown]
# ___
# ### Import libraries and sub-libraries.

# %%
import os
import numpy as np
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import matplotlib.pyplot as plt
from torchvision.transforms import functional as TF
import torch.nn.functional as F
from torchmetrics.image.psnr import PeakSignalNoiseRatio
from torchmetrics.image.ssim import StructuralSimilarityIndexMeasure
# You can install torchmeterics using: pip install torchmetrics

# %% [markdown]
# ___
# ### Calling a custom code to change the default font for figures to `Computer Modern`. (Optional)

# %%
# from fontsetting import font_cmu
# plt = font_cmu(plt)

# %% [markdown]
# ___
# ### Check the hardware that is at your disposal

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Device available:', device)
# Out:
# Device available: cuda

# %% [markdown]
# ___
# ### Read training data from `data/train/hig-res` and `data/train/low-res`

# %%
# Loading TIFF images for Super-resolution
class TIFFDataset(Dataset):
    def __init__(self, high_res_dir, low_res_dir, transform=None):
        self.high_res_dir = high_res_dir
        self.low_res_dir = low_res_dir
        self.transform = transform
        self.filenames = sorted([f for f in os.listdir(high_res_dir) if f.endswith('.tif')])
    
    # Get the number of samples in the dataset
    def __len__(self):
        return len(self.filenames)

    # Get the sample at the given index
    def __getitem__(self, idx):
        high_res_path = os.path.join(self.high_res_dir, self.filenames[idx])
        low_res_path = os.path.join(self.low_res_dir, self.filenames[idx])

        # Load images
        high_res = Image.open(high_res_path)
        low_res = Image.open(low_res_path)

        # Resize low-res to 128x128 (ensuring correct input size)
        low_res = low_res.resize((128, 128), Image.BICUBIC)

        # Apply transformations
        if self.transform:
            high_res = self.transform(high_res)
            low_res = self.transform(low_res)

        return low_res, high_res  # Returning input-output pairs

# Define a transform to convert images to PyTorch tensors
transform = transforms.Compose([
    transforms.ToTensor()
])

# Create the dataset for training images
train_dataset = TIFFDataset('data/train/high-res', 'data/train/low-res', transform=transform)

# Function to create data loader
def create_loader(dataset, batch_size):
    torch.manual_seed(0)  # For reproducibility
    return DataLoader(dataset, batch_size=batch_size, shuffle=True)

# Print dataset size
dataset_size = len(train_dataset)
print('Number of images in the dataset:', dataset_size)
# Out:
# Number of images in the dataset: 240

# %% [markdown]
# ___
# ### Define a super-resolution network
#
# #### Here, I have defined a trivial network, which has only two layers and no activation function. We are essentially doing linear filtering.

# %%
class TrivialNet(nn.Module):
    def __init__(self):
        super(TrivialNet, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=12, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(in_channels=12, out_channels=1, kernel_size=3, padding=1)

    def forward(self, x):
        x = self.conv1(x)  # First conv layer
        x = self.conv2(x)  # Output layer
        return x

# %% [markdown]
# ___
# ### Create a function to execute training. Note, we will call this function later.

# %%
def train_model(model, opt, criterion, train_loader, num_epoch):
    avg_train_losses = []

    for epoch in range(num_epoch):  # Loop over the dataset multiple times
        model.train()
        total_train_loss = 0

        for i, (x_tr_batch, y_tr_batch) in enumerate(train_loader):  # Loop over mini-batches
            x_tr_batch, y_tr_batch = x_tr_batch.to(device), y_tr_batch.to(device)

            # Upsample low-resolution input to 256x256
            x_tr_batch = torch.nn.functional.interpolate(x_tr_batch, scale_factor=2, mode='bicubic', align_corners=False)

            opt.zero_grad()  # Delete previous gradients
            y_hat_tr_batch = model(x_tr_batch)  # Forward pass
            loss = criterion(y_hat_tr_batch, y_tr_batch)  # Compute loss
            loss.backward()  # Backward pass
            opt.step()  # Update weights
            total_train_loss += loss.item()  # Accumulate loss

            if (i + 1) % 10 == 0:
                print(f'Epoch {epoch+1}, Iteration {i+1}, Loss: {loss.item():.6f}')

        avg_train_loss = total_train_loss / len(train_loader)  # Compute average loss
        avg_train_losses.append(avg_train_loss)  # Store average loss

    # Plot training loss
    fig, ax = plt.subplots(figsize=(8, 5))
    ax.plot(range(1, num_epoch + 1), avg_train_losses, label='training loss')
    ax.set_xlabel('epochs')
    ax.set_ylabel('MSE loss')
    ax.set_yscale('log')  # Log scale for better visualization
    ax.set_title('training loss')
    ax.grid(True)
    ax.legend()
    plt.show()

# %% [markdown]
# ___
# ### Now, let us define hyperparameters and train the network.
#
# #### Note, in addition to the parameters that controls the network architecture or the training process, you need to select/initialize (i) a data loader, (ii) a model, (iii) an optimizer, and (iv) a loss function.

# %%
batch_size = 5  # Number of complete images in each batch
lr = 1e-3  # Learning rate
num_epoch = 100  # Epochs

# Model, criterion, and optimizer
train_loader = create_loader(train_dataset, batch_size)
model = TrivialNet().to(device)  # Pick a model and move to GPU/CPU
opt = optim.Adam(model.parameters(), lr=lr)  # Pick an optimizer
criterion = nn.MSELoss()  # Pick a loss function

# Train the model
train_model(model, opt, criterion, train_loader, num_epoch)
# Out:
# Epoch 1, Iteration 10, Loss: 0.003035
# Epoch 1, Iteration 20, Loss: 0.002330
# Epoch 1, Iteration 30, Loss: 0.002499
# Epoch 1, Iteration 40, Loss: 0.001856
# Epoch 2, Iteration 10, Loss: 0.001604
# Epoch 2, Iteration 20, Loss: 0.001476
# Epoch 2, Iteration 30, Loss: 0.001363
# Epoch 2, Iteration 40, Loss: 0.001290
# Epoch 3, Iteration 10, Loss: 0.001389
# Epoch 3, Iteration 20, Loss: 0.001133
# Epoch 3, Iteration 30, Loss: 0.001107
# Epoch 3, Iteration 40, Loss: 0.001059
# Epoch 4, Iteration 10, Loss: 0.000968
# Epoch 4, Iteration 20, Loss: 0.000959
# Epoch 4, Iteration 30, Loss: 0.000824
# Epoch 4, Iteration 40, Loss: 0.000846
# Epoch 5, Iteration 10, Loss: 0.000868
# Epoch 5, Iteration 20, Loss: 0.000728
# Epoch 5, Iteration 30, Loss: 0.000726
# Epoch 5, Iteration 40, Loss: 0.000799
# Epoch 6, Iteration 10, Loss: 0.000848
# Epoch 6, Iteration 20, Loss: 0.000755
# Epoch 6, Iteration 30, Loss: 0.000804
# Epoch 6, Iteration 40, Loss: 0.000649
# Epoch 7, Iteration 10, Loss: 0.000699
# Epoch 7, Iteration 20, Loss: 0.000686
# Epoch 7, Iteration 30, Loss: 0.000686
# Epoch 7, Iteration 40, Loss: 0.000852
# Epoch 8, Iteration 10, Loss: 0.000788
# Epoch 8, Iteration 20, Loss: 0.000658
# Epoch 8, Iteration 30, Loss: 0.000739
# Epoch 8, Iteration 40, Loss: 0.000618
# Epoch 9, Iteration 10, Loss: 0.000796
# Epoch 9, Iteration 20, Loss: 0.000636
# Epoch 9, Iteration 30, Loss: 0.000702
# Epoch 9, Iteration 40, Loss: 0.000661
# Epoch 10, Iteration 10, Loss: 0.000682
# Epoch 10, Iteration 20, Loss: 0.000749
# Epoch 10, Iteration 30, Loss: 0.000586
# Epoch 10, Iteration 40, Loss: 0.000589
# Epoch 11, Iteration 10, Loss: 0.000706
# Epoch 11, Iteration 20, Loss: 0.000683
# Epoch 11, Iteration 30, Loss: 0.000643
# Epoch 11, Iteration 40, Loss: 0.000560
# Epoch 12, Iteration 10, Loss: 0.000622
# Epoch 12, Iteration 20, Loss: 0.000605
# Epoch 12, Iteration 30, Loss: 0.000750
# Epoch 12, Iteration 40, Loss: 0.000746
# Epoch 13, Iteration 10, Loss: 0.000656
# Epoch 13, Iteration 20, Loss: 0.000532
# Epoch 13, Iteration 30, Loss: 0.000528
# Epoch 13, Iteration 40, Loss: 0.000456
# Epoch 14, Iteration 10, Loss: 0.000650
# Epoch 14, Iteration 20, Loss: 0.000634
# Epoch 14, Iteration 30, Loss: 0.000535
# Epoch 14, Iteration 40, Loss: 0.000583
# Epoch 15, Iteration 10, Loss: 0.000495
# Epoch 15, Iteration 20, Loss: 0.000620
# Epoch 15, Iteration 30, Loss: 0.000654
# Epoch 15, Iteration 40, Loss: 0.000580
# Epoch 16, Iteration 10, Loss: 0.000560
# Epoch 16, Iteration 20, Loss: 0.000601
# Epoch 16, Iteration 30, Loss: 0.000530
# Epoch 16, Iteration 40, Loss: 0.000626
# Epoch 17, Iteration 10, Loss: 0.000556
# Epoch 17, Iteration 20, Loss: 0.000590
# Epoch 17, Iteration 30, Loss: 0.000628
# Epoch 17, Iteration 40, Loss: 0.000649
# Epoch 18, Iteration 10, Loss: 0.000586
# Epoch 18, Iteration 20, Loss: 0.000489
# Epoch 18, Iteration 30, Loss: 0.000577
# Epoch 18, Iteration 40, Loss: 0.000520
# Epoch 19, Iteration 10, Loss: 0.000602
# Epoch 19, Iteration 20, Loss: 0.000624
# Epoch 19, Iteration 30, Loss: 0.000583
# Epoch 19, Iteration 40, Loss: 0.000534
# Epoch 20, Iteration 10, Loss: 0.000690
# Epoch 20, Iteration 20, Loss: 0.000574
# Epoch 20, Iteration 30, Loss: 0.000604
# Epoch 20, Iteration 40, Loss: 0.000649
# Epoch 21, Iteration 10, Loss: 0.000424
# Epoch 21, Iteration 20, Loss: 0.000505
# Epoch 21, Iteration 30, Loss: 0.000628
# Epoch 21, Iteration 40, Loss: 0.000594
# Epoch 22, Iteration 10, Loss: 0.000518
# Epoch 22, Iteration 20, Loss: 0.000569
# Epoch 22, Iteration 30, Loss: 0.000515
# Epoch 22, Iteration 40, Loss: 0.000633
# Epoch 23, Iteration 10, Loss: 0.000615
# Epoch 23, Iteration 20, Loss: 0.000570
# Epoch 23, Iteration 30, Loss: 0.000585
# Epoch 23, Iteration 40, Loss: 0.000626
# Epoch 24, Iteration 10, Loss: 0.000599
# Epoch 24, Iteration 20, Loss: 0.000592
# Epoch 24, Iteration 30, Loss: 0.000441
# Epoch 24, Iteration 40, Loss: 0.000494
# Epoch 25, Iteration 10, Loss: 0.000606
# Epoch 25, Iteration 20, Loss: 0.000594
# Epoch 25, Iteration 30, Loss: 0.000683
# Epoch 25, Iteration 40, Loss: 0.000604
# Epoch 26, Iteration 10, Loss: 0.000498
# Epoch 26, Iteration 20, Loss: 0.000475
# Epoch 26, Iteration 30, Loss: 0.000547
# Epoch 26, Iteration 40, Loss: 0.000565
# Epoch 27, Iteration 10, Loss: 0.000569
# Epoch 27, Iteration 20, Loss: 0.000560
# Epoch 27, Iteration 30, Loss: 0.000570
# Epoch 27, Iteration 40, Loss: 0.000532
# Epoch 28, Iteration 10, Loss: 0.000627
# Epoch 28, Iteration 20, Loss: 0.000529
# Epoch 28, Iteration 30, Loss: 0.000432
# Epoch 28, Iteration 40, Loss: 0.000540
# Epoch 29, Iteration 10, Loss: 0.000664
# Epoch 29, Iteration 20, Loss: 0.000508
# Epoch 29, Iteration 30, Loss: 0.000630
# Epoch 29, Iteration 40, Loss: 0.000492
# Epoch 30, Iteration 10, Loss: 0.000559
# Epoch 30, Iteration 20, Loss: 0.000537
# Epoch 30, Iteration 30, Loss: 0.000585
# Epoch 30, Iteration 40, Loss: 0.000580
# Epoch 31, Iteration 10, Loss: 0.000544
# Epoch 31, Iteration 20, Loss: 0.000571
# Epoch 31, Iteration 30, Loss: 0.000489
# Epoch 31, Iteration 40, Loss: 0.000540
# Epoch 32, Iteration 10, Loss: 0.000573
# Epoch 32, Iteration 20, Loss: 0.000563
# Epoch 32, Iteration 30, Loss: 0.000573
# Epoch 32, Iteration 40, Loss: 0.000577
# Epoch 33, Iteration 10, Loss: 0.000549
# Epoch 33, Iteration 20, Loss: 0.000482
# Epoch 33, Iteration 30, Loss: 0.000617
# Epoch 33, Iteration 40, Loss: 0.000604
# Epoch 34, Iteration 10, Loss: 0.000563
# Epoch 34, Iteration 20, Loss: 0.000466
# Epoch 34, Iteration 30, Loss: 0.000558
# Epoch 34, Iteration 40, Loss: 0.000528
# Epoch 35, Iteration 10, Loss: 0.000544
# Epoch 35, Iteration 20, Loss: 0.000710
# Epoch 35, Iteration 30, Loss: 0.000506
# Epoch 35, Iteration 40, Loss: 0.000517
# Epoch 36, Iteration 10, Loss: 0.000486
# Epoch 36, Iteration 20, Loss: 0.000561
# Epoch 36, Iteration 30, Loss: 0.000504
# Epoch 36, Iteration 40, Loss: 0.000481
# Epoch 37, Iteration 10, Loss: 0.000437
# Epoch 37, Iteration 20, Loss: 0.000523
# Epoch 37, Iteration 30, Loss: 0.000583
# Epoch 37, Iteration 40, Loss: 0.000567
# Epoch 38, Iteration 10, Loss: 0.000492
# Epoch 38, Iteration 20, Loss: 0.000510
# Epoch 38, Iteration 30, Loss: 0.000638
# Epoch 38, Iteration 40, Loss: 0.000452
# Epoch 39, Iteration 10, Loss: 0.000481
# Epoch 39, Iteration 20, Loss: 0.000559
# Epoch 39, Iteration 30, Loss: 0.000477
# Epoch 39, Iteration 40, Loss: 0.000497
# Epoch 40, Iteration 10, Loss: 0.000451
# Epoch 40, Iteration 20, Loss: 0.000530
# Epoch 40, Iteration 30, Loss: 0.000529
# Epoch 40, Iteration 40, Loss: 0.000521
# Epoch 41, Iteration 10, Loss: 0.000497
# Epoch 41, Iteration 20, Loss: 0.000509
# Epoch 41, Iteration 30, Loss: 0.000554
# Epoch 41, Iteration 40, Loss: 0.000548
# Epoch 42, Iteration 10, Loss: 0.000471
# Epoch 42, Iteration 20, Loss: 0.000610
# Epoch 42, Iteration 30, Loss: 0.000532
# Epoch 42, Iteration 40, Loss: 0.000488
# Epoch 43, Iteration 10, Loss: 0.000427
# Epoch 43, Iteration 20, Loss: 0.000492
# Epoch 43, Iteration 30, Loss: 0.000484
# Epoch 43, Iteration 40, Loss: 0.000502
# Epoch 44, Iteration 10, Loss: 0.000539
# Epoch 44, Iteration 20, Loss: 0.000513
# Epoch 44, Iteration 30, Loss: 0.000484
# Epoch 44, Iteration 40, Loss: 0.000552
# Epoch 45, Iteration 10, Loss: 0.000532
# Epoch 45, Iteration 20, Loss: 0.000446
# Epoch 45, Iteration 30, Loss: 0.000489
# Epoch 45, Iteration 40, Loss: 0.000553
# Epoch 46, Iteration 10, Loss: 0.000547
# Epoch 46, Iteration 20, Loss: 0.000505
# Epoch 46, Iteration 30, Loss: 0.000524
# Epoch 46, Iteration 40, Loss: 0.000570
# Epoch 47, Iteration 10, Loss: 0.000440
# Epoch 47, Iteration 20, Loss: 0.000530
# Epoch 47, Iteration 30, Loss: 0.000487
# Epoch 47, Iteration 40, Loss: 0.000584
# Epoch 48, Iteration 10, Loss: 0.000481
# Epoch 48, Iteration 20, Loss: 0.000465
# Epoch 48, Iteration 30, Loss: 0.000541
# Epoch 48, Iteration 40, Loss: 0.000533
# Epoch 49, Iteration 10, Loss: 0.000510
# Epoch 49, Iteration 20, Loss: 0.000567
# Epoch 49, Iteration 30, Loss: 0.000496
# Epoch 49, Iteration 40, Loss: 0.000386
# Epoch 50, Iteration 10, Loss: 0.000645
# Epoch 50, Iteration 20, Loss: 0.000536
# Epoch 50, Iteration 30, Loss: 0.000522
# Epoch 50, Iteration 40, Loss: 0.000528
# Epoch 51, Iteration 10, Loss: 0.000457
# Epoch 51, Iteration 20, Loss: 0.000640
# Epoch 51, Iteration 30, Loss: 0.000519
# Epoch 51, Iteration 40, Loss: 0.000537
# Epoch 52, Iteration 10, Loss: 0.000502
# Epoch 52, Iteration 20, Loss: 0.000388
# Epoch 52, Iteration 30, Loss: 0.000518
# Epoch 52, Iteration 40, Loss: 0.000473
# Epoch 53, Iteration 10, Loss: 0.000527
# Epoch 53, Iteration 20, Loss: 0.000429
# Epoch 53, Iteration 30, Loss: 0.000520
# Epoch 53, Iteration 40, Loss: 0.000498
# Epoch 54, Iteration 10, Loss: 0.000516
# Epoch 54, Iteration 20, Loss: 0.000517
# Epoch 54, Iteration 30, Loss: 0.000550
# Epoch 54, Iteration 40, Loss: 0.000472
# Epoch 55, Iteration 10, Loss: 0.000530
# Epoch 55, Iteration 20, Loss: 0.000389
# Epoch 55, Iteration 30, Loss: 0.000516
# Epoch 55, Iteration 40, Loss: 0.000473
# Epoch 56, Iteration 10, Loss: 0.000536
# Epoch 56, Iteration 20, Loss: 0.000433
# Epoch 56, Iteration 30, Loss: 0.000483
# Epoch 56, Iteration 40, Loss: 0.000637
# Epoch 57, Iteration 10, Loss: 0.000518
# Epoch 57, Iteration 20, Loss: 0.000569
# Epoch 57, Iteration 30, Loss: 0.000478
# Epoch 57, Iteration 40, Loss: 0.000480
# Epoch 58, Iteration 10, Loss: 0.000528
# Epoch 58, Iteration 20, Loss: 0.000494
# Epoch 58, Iteration 30, Loss: 0.000488
# Epoch 58, Iteration 40, Loss: 0.000540
# Epoch 59, Iteration 10, Loss: 0.000516
# Epoch 59, Iteration 20, Loss: 0.000502
# Epoch 59, Iteration 30, Loss: 0.000528
# Epoch 59, Iteration 40, Loss: 0.000550
# Epoch 60, Iteration 10, Loss: 0.000566
# Epoch 60, Iteration 20, Loss: 0.000574
# Epoch 60, Iteration 30, Loss: 0.000603
# Epoch 60, Iteration 40, Loss: 0.000523
# Epoch 61, Iteration 10, Loss: 0.000561
# Epoch 61, Iteration 20, Loss: 0.000493
# Epoch 61, Iteration 30, Loss: 0.000496
# Epoch 61, Iteration 40, Loss: 0.000527
# Epoch 62, Iteration 10, Loss: 0.000500
# Epoch 62, Iteration 20, Loss: 0.000438
# Epoch 62, Iteration 30, Loss: 0.000605
# Epoch 62, Iteration 40, Loss: 0.000484
# Epoch 63, Iteration 10, Loss: 0.000503
# Epoch 63, Iteration 20, Loss: 0.000526
# Epoch 63, Iteration 30, Loss: 0.000484
# Epoch 63, Iteration 40, Loss: 0.000522
# Epoch 64, Iteration 10, Loss: 0.000521
# Epoch 64, Iteration 20, Loss: 0.000509
# Epoch 64, Iteration 30, Loss: 0.000522
# Epoch 64, Iteration 40, Loss: 0.000476
# Epoch 65, Iteration 10, Loss: 0.000542
# Epoch 65, Iteration 20, Loss: 0.000541
# Epoch 65, Iteration 30, Loss: 0.000499
# Epoch 65, Iteration 40, Loss: 0.000543
# Epoch 66, Iteration 10, Loss: 0.000524
# Epoch 66, Iteration 20, Loss: 0.000499
# Epoch 66, Iteration 30, Loss: 0.000482
# Epoch 66, Iteration 40, Loss: 0.000473
# Epoch 67, Iteration 10, Loss: 0.000537
# Epoch 67, Iteration 20, Loss: 0.000495
# Epoch 67, Iteration 30, Loss: 0.000625
# Epoch 67, Iteration 40, Loss: 0.000476
# Epoch 68, Iteration 10, Loss: 0.000572
# Epoch 68, Iteration 20, Loss: 0.000500
# Epoch 68, Iteration 30, Loss: 0.000489
# Epoch 68, Iteration 40, Loss: 0.000560
# Epoch 69, Iteration 10, Loss: 0.000444
# Epoch 69, Iteration 20, Loss: 0.000389
# Epoch 69, Iteration 30, Loss: 0.000507
# Epoch 69, Iteration 40, Loss: 0.000484
# Epoch 70, Iteration 10, Loss: 0.000496
# Epoch 70, Iteration 20, Loss: 0.000556
# Epoch 70, Iteration 30, Loss: 0.000531
# Epoch 70, Iteration 40, Loss: 0.000548
# Epoch 71, Iteration 10, Loss: 0.000434
# Epoch 71, Iteration 20, Loss: 0.000464
# Epoch 71, Iteration 30, Loss: 0.000458
# Epoch 71, Iteration 40, Loss: 0.000508
# Epoch 72, Iteration 10, Loss: 0.000562
# Epoch 72, Iteration 20, Loss: 0.000493
# Epoch 72, Iteration 30, Loss: 0.000528
# Epoch 72, Iteration 40, Loss: 0.000426
# Epoch 73, Iteration 10, Loss: 0.000561
# Epoch 73, Iteration 20, Loss: 0.000491
# Epoch 73, Iteration 30, Loss: 0.000641
# Epoch 73, Iteration 40, Loss: 0.000534
# Epoch 74, Iteration 10, Loss: 0.000466
# Epoch 74, Iteration 20, Loss: 0.000452
# Epoch 74, Iteration 30, Loss: 0.000619
# Epoch 74, Iteration 40, Loss: 0.000563
# Epoch 75, Iteration 10, Loss: 0.000508
# Epoch 75, Iteration 20, Loss: 0.000526
# Epoch 75, Iteration 30, Loss: 0.000427
# Epoch 75, Iteration 40, Loss: 0.000595
# Epoch 76, Iteration 10, Loss: 0.000524
# Epoch 76, Iteration 20, Loss: 0.000494
# Epoch 76, Iteration 30, Loss: 0.000416
# Epoch 76, Iteration 40, Loss: 0.000582
# Epoch 77, Iteration 10, Loss: 0.000497
# Epoch 77, Iteration 20, Loss: 0.000570
# Epoch 77, Iteration 30, Loss: 0.000457
# Epoch 77, Iteration 40, Loss: 0.000518
# Epoch 78, Iteration 10, Loss: 0.000485
# Epoch 78, Iteration 20, Loss: 0.000453
# Epoch 78, Iteration 30, Loss: 0.000513
# Epoch 78, Iteration 40, Loss: 0.000541
# Epoch 79, Iteration 10, Loss: 0.000446
# Epoch 79, Iteration 20, Loss: 0.000482
# Epoch 79, Iteration 30, Loss: 0.000437
# Epoch 79, Iteration 40, Loss: 0.000528
# Epoch 80, Iteration 10, Loss: 0.000539
# Epoch 80, Iteration 20, Loss: 0.000535
# Epoch 80, Iteration 30, Loss: 0.000496
# Epoch 80, Iteration 40, Loss: 0.000543
# Epoch 81, Iteration 10, Loss: 0.000531
# Epoch 81, Iteration 20, Loss: 0.000568
# Epoch 81, Iteration 30, Loss: 0.000452
# Epoch 81, Iteration 40, Loss: 0.000675
# Epoch 82, Iteration 10, Loss: 0.000504
# Epoch 82, Iteration 20, Loss: 0.000554
# Epoch 82, Iteration 30, Loss: 0.000471
# Epoch 82, Iteration 40, Loss: 0.000547
# Epoch 83, Iteration 10, Loss: 0.000531
# Epoch 83, Iteration 20, Loss: 0.000488
# Epoch 83, Iteration 30, Loss: 0.000643
# Epoch 83, Iteration 40, Loss: 0.000511
# Epoch 84, Iteration 10, Loss: 0.000470
# Epoch 84, Iteration 20, Loss: 0.000514
# Epoch 84, Iteration 30, Loss: 0.000466
# Epoch 84, Iteration 40, Loss: 0.000504
# Epoch 85, Iteration 10, Loss: 0.000432
# Epoch 85, Iteration 20, Loss: 0.000521
# Epoch 85, Iteration 30, Loss: 0.000551
# Epoch 85, Iteration 40, Loss: 0.000563
# Epoch 86, Iteration 10, Loss: 0.000471
# Epoch 86, Iteration 20, Loss: 0.000552
# Epoch 86, Iteration 30, Loss: 0.000494
# Epoch 86, Iteration 40, Loss: 0.000478
# Epoch 87, Iteration 10, Loss: 0.000480
# Epoch 87, Iteration 20, Loss: 0.000396
# Epoch 87, Iteration 30, Loss: 0.000471
# Epoch 87, Iteration 40, Loss: 0.000550
# Epoch 88, Iteration 10, Loss: 0.000504
# Epoch 88, Iteration 20, Loss: 0.000461
# Epoch 88, Iteration 30, Loss: 0.000526
# Epoch 88, Iteration 40, Loss: 0.000443
# Epoch 89, Iteration 10, Loss: 0.000512
# Epoch 89, Iteration 20, Loss: 0.000422
# Epoch 89, Iteration 30, Loss: 0.000505
# Epoch 89, Iteration 40, Loss: 0.000506
# Epoch 90, Iteration 10, Loss: 0.000451
# Epoch 90, Iteration 20, Loss: 0.000449
# Epoch 90, Iteration 30, Loss: 0.000447
# Epoch 90, Iteration 40, Loss: 0.000486
# Epoch 91, Iteration 10, Loss: 0.000495
# Epoch 91, Iteration 20, Loss: 0.000535
# Epoch 91, Iteration 30, Loss: 0.000568
# Epoch 91, Iteration 40, Loss: 0.000505
# Epoch 92, Iteration 10, Loss: 0.000498
# Epoch 92, Iteration 20, Loss: 0.000572
# Epoch 92, Iteration 30, Loss: 0.000502
# Epoch 92, Iteration 40, Loss: 0.000505
# Epoch 93, Iteration 10, Loss: 0.000494
# Epoch 93, Iteration 20, Loss: 0.000532
# Epoch 93, Iteration 30, Loss: 0.000584
# Epoch 93, Iteration 40, Loss: 0.000566
# Epoch 94, Iteration 10, Loss: 0.000572
# Epoch 94, Iteration 20, Loss: 0.000482
# Epoch 94, Iteration 30, Loss: 0.000502
# Epoch 94, Iteration 40, Loss: 0.000529
# Epoch 95, Iteration 10, Loss: 0.000544
# Epoch 95, Iteration 20, Loss: 0.000548
# Epoch 95, Iteration 30, Loss: 0.000482
# Epoch 95, Iteration 40, Loss: 0.000422
# Epoch 96, Iteration 10, Loss: 0.000477
# Epoch 96, Iteration 20, Loss: 0.000490
# Epoch 96, Iteration 30, Loss: 0.000505
# Epoch 96, Iteration 40, Loss: 0.000428
# Epoch 97, Iteration 10, Loss: 0.000501
# Epoch 97, Iteration 20, Loss: 0.000543
# Epoch 97, Iteration 30, Loss: 0.000456
# Epoch 97, Iteration 40, Loss: 0.000484
# Epoch 98, Iteration 10, Loss: 0.000509
# Epoch 98, Iteration 20, Loss: 0.000394
# Epoch 98, Iteration 30, Loss: 0.000524
# Epoch 98, Iteration 40, Loss: 0.000467
# Epoch 99, Iteration 10, Loss: 0.000563
# Epoch 99, Iteration 20, Loss: 0.000571
# Epoch 99, Iteration 30, Loss: 0.000495
# Epoch 99, Iteration 40, Loss: 0.000562
# Epoch 100, Iteration 10, Loss: 0.000542
# Epoch 100, Iteration 20, Loss: 0.000496
# Epoch 100, Iteration 30, Loss: 0.000588
# Epoch 100, Iteration 40, Loss: 0.000590

# %% [markdown]
# ___
# ### Apply it one of the validation image

# %%
# Create the dataset for validation images
val_dataset = TIFFDataset('data/val/high-res', 'data/val/low-res', transform=transform)

# Load one (low-res, high-res) image pair from validation dataset and move it to the dedvice
val_low_res, val_high_res = val_dataset[1]  # Input (128x128), Ground truth (256x256)
val_low_res, val_high_res = val_low_res.to(device), val_high_res.to(device)

# Upsample low-resolution image to 256x256 for both model input and error visualization
val_low_res_interpolated = torch.nn.functional.interpolate(val_low_res.unsqueeze(0), scale_factor=2, mode='bicubic', align_corners=False).squeeze(0)

# Apply the trained model to super-resolve the interpolated low-res image
val_super_res = model(val_low_res_interpolated.unsqueeze(0)).detach().squeeze(0)  # Remove batch dimension

# Convert tensors to numpy for visualization
val_low_res_np = val_low_res_interpolated.squeeze().cpu().numpy()  # Use the interpolated version for error maps
val_high_res_np = val_high_res.squeeze().cpu().numpy()
val_super_res_np = val_super_res.squeeze().cpu().numpy()

# Plot an example image and error maps
fig, ax = plt.subplots(2, 3, figsize=(10, 7))

# Plot images
ax[0, 0].imshow(val_high_res_np, cmap='gray', vmin=0, vmax=1)
ax[0, 0].set_title('ground truth (high-res)')
ax[0, 0].axis('off')

ax[0, 1].imshow(val_low_res_np, cmap='gray', vmin=0, vmax=1)
ax[0, 1].set_title('interpolated low-res image')
ax[0, 1].axis('off')

ax[0, 2].imshow(val_super_res_np, cmap='gray', vmin=0, vmax=1)
ax[0, 2].set_title('super-resolved image')
ax[0, 2].axis('off')

# Error maps
ax[1, 0].imshow(5 * np.abs(val_high_res_np - val_high_res_np), cmap='gray', vmin=0, vmax=1)
ax[1, 0].axis('off')
ax[1, 0].text(0.02, 0.98, r'$\times 5$', transform=ax[1, 0].transAxes, fontsize=14, va='top', ha='left', color='white')

ax[1, 1].imshow(5 * np.abs(val_high_res_np - val_low_res_np), cmap='gray', vmin=0, vmax=1)
ax[1, 1].axis('off')
ax[1, 1].text(0.02, 0.98, r'$\times 5$', transform=ax[1, 1].transAxes, fontsize=14, va='top', ha='left', color='white')

ax[1, 2].imshow(5 * np.abs(val_high_res_np - val_super_res_np), cmap='gray', vmin=0, vmax=1)
ax[1, 2].axis('off')
ax[1, 2].text(0.02, 0.98, r'$\times 5$', transform=ax[1, 2].transAxes, fontsize=14, va='top', ha='left', color='white')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Compute PSNR and SSIM over the entire validation dataset

# %%
# Initialize metrics
psnr_metric = PeakSignalNoiseRatio().to(device)
ssim_metric = StructuralSimilarityIndexMeasure(data_range=1.0).to(device)

# Accumulators
total_psnr_interpolated = 0
total_psnr_super_resolved = 0
total_ssim_interpolated = 0
total_ssim_super_resolved = 0
num_samples = len(val_dataset)

# Loop over validation set
for i in range(num_samples):
    val_low_res, val_high_res = val_dataset[i]
    val_low_res, val_high_res = val_low_res.to(device), val_high_res.to(device)

    # Compute data range dynamically
    data_range = val_high_res.max() - val_high_res.min()
    ssim_metric.data_range = data_range

    # Upsample low-res image
    val_low_res_up = torch.nn.functional.interpolate(val_low_res.unsqueeze(0), scale_factor=2, mode='bicubic', align_corners=False)
    val_high_res = val_high_res.unsqueeze(0)  # Add batch dim
    val_super_res = model(val_low_res_up).detach()

    # PSNR
    psnr_interp = psnr_metric(val_low_res_up, val_high_res).item()
    psnr_sr = psnr_metric(val_super_res, val_high_res).item()

    # SSIM (data_range is now set in metric initialization)
    ssim_interp = ssim_metric(val_low_res_up, val_high_res).item()
    ssim_sr = ssim_metric(val_super_res, val_high_res).item()

    # Accumulate
    total_psnr_interpolated += psnr_interp
    total_psnr_super_resolved += psnr_sr
    total_ssim_interpolated += ssim_interp
    total_ssim_super_resolved += ssim_sr

# Averages
avg_psnr_interp = total_psnr_interpolated / num_samples
avg_psnr_sr = total_psnr_super_resolved / num_samples
avg_ssim_interp = total_ssim_interpolated / num_samples
avg_ssim_sr = total_ssim_super_resolved / num_samples

# Scores
avg_sr_score = avg_psnr_sr + (avg_ssim_sr * 40)
avg_interp_score = avg_psnr_interp + (avg_ssim_interp * 40)

# Print results
print(f'Average PSNR (interpolated): {avg_psnr_interp:.2f} dB')
print(f'Average PSNR (super-resolved): {avg_psnr_sr:.2f} dB')
print(f'Average SSIM (interpolated): {avg_ssim_interp:.4f}')
print(f'Average SSIM (super-resolved): {avg_ssim_sr:.4f}')
print(f'Average score (interpolated): {avg_interp_score:.2f}')
print(f'Average score (super-resolved): {avg_sr_score:.2f}')
# Out:
# Average PSNR (interpolated): 30.81 dB
# Average PSNR (super-resolved): 33.25 dB
# Average SSIM (interpolated): 0.9056
# Average SSIM (super-resolved): 0.9403
# Average score (interpolated): 67.04
# Average score (super-resolved): 70.86
