# %% [markdown]
# ___
# # **Starter code for BME 5710 project**
# ## Instructor -- Rizwan Ahmad (ahmad.46@osu.edu)
# ## BME5710 -- Spring 2025

# %% [markdown]
# ___
# ### Import libraries and sub-libraries.

# %%
import os
import numpy as np
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import matplotlib.pyplot as plt
from torchvision.transforms import functional as TF
import torch.nn.functional as F
from torchmetrics.image.psnr import PeakSignalNoiseRatio
from torchmetrics.image.ssim import StructuralSimilarityIndexMeasure
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("GPU name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# You can install torchmeterics using: pip install torchmetrics
# Out:
# PyTorch version: 2.5.1+cu121
# CUDA available: True
# GPU name: NVIDIA GeForce RTX 3050 Ti Laptop GPU

# %% [markdown]
# ___
# ### Calling a custom code to change the default font for figures to `Computer Modern`. (Optional)

# %%
#from fontsetting import font_cmu
#plt = font_cmu(plt)
# Disable LaTeX
#plt.rcParams['text.usetex'] = False

# %% [markdown]
# ___
# ### Check and set hardware (CUDA vs CPU)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Device available:', device)
# Out:
# Device available: cuda

# %% [markdown]
# ___
# ### Read training data from `data/train/hig-res` and `data/train/low-res`

# %%
# Loading TIFF images for Super-resolution
class TIFFDataset(Dataset):
    def __init__(self, high_res_dir, low_res_dir, transform=None):
        self.high_res_dir = high_res_dir
        self.low_res_dir = low_res_dir
        self.transform = transform
        self.filenames = sorted([f for f in os.listdir(high_res_dir) if f.endswith('.tif')])
    
    # Get the number of samples in the dataset
    def __len__(self):
        return len(self.filenames)

    # Get the sample at the given index
    def __getitem__(self, idx):
        high_res_path = os.path.join(self.high_res_dir, self.filenames[idx])
        low_res_path = os.path.join(self.low_res_dir, self.filenames[idx])

        # Load images
        high_res = Image.open(high_res_path)
        low_res = Image.open(low_res_path)

        # Resize low-res to 128x128 (ensuring correct input size)
        low_res = low_res.resize((128, 128), Image.BICUBIC)

        # Apply transformations
        if self.transform:
            high_res = self.transform(high_res)
            low_res = self.transform(low_res)

        return low_res, high_res  # Returning input-output pairs

# Define a transform to convert images to PyTorch tensors
transform = transforms.Compose([
    transforms.ToTensor()
])

# Create the dataset for training images
train_dataset = TIFFDataset('data/train/high-res', 'data/train/low-res', transform=transform)

# Function to create data loader
def create_loader(dataset, batch_size):
    torch.manual_seed(0)  # For reproducibility
    return DataLoader(dataset, batch_size=batch_size, shuffle=True)

# Print dataset size
dataset_size = len(train_dataset)
print('Number of images in the dataset:', dataset_size)
# Out:
# Number of images in the dataset: 240

# %% [markdown]
# ___
# ### define a super-resolution network

# %%
import torch.nn.functional as F

class ResidualBlock(nn.Module):
    def __init__(self, channels):
        super(ResidualBlock, self).__init__()
        self.block = nn.Sequential(
            nn.Conv2d(channels, channels, kernel_size=3, padding=1),
            nn.GroupNorm(8, channels),
            nn.GELU(),
            nn.Conv2d(channels, channels, kernel_size=3, padding=1),
            nn.GroupNorm(8, channels)
        )

    def forward(self, x):
        return x + self.block(x)

class Down(nn.Module):
    def __init__(self, in_channels, out_channels, dropout_rate=0.1):
        super(Down, self).__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=2, padding=1),
            nn.GELU(),
            ResidualBlock(out_channels),
            nn.Dropout(dropout_rate)
        )

    def forward(self, x):
        return self.block(x)

class Up(nn.Module):
    def __init__(self, in_channels, out_channels, bilinear=False, dropout_rate=0.1):
        super(Up, self).__init__()
        if bilinear:
            self.up = nn.Sequential(
                nn.Upsample(scale_factor=2, mode='bilinear', align_corners=False),
                nn.Conv2d(in_channels, out_channels, kernel_size=1)
            )
        else:
            self.up = nn.ConvTranspose2d(in_channels, out_channels, kernel_size=2, stride=2)
        
        self.res_block = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.GELU(),
            ResidualBlock(out_channels),
            nn.Dropout(dropout_rate)
        )

    def forward(self, x1, x2):
        x1 = self.up(x1)
        # Ensure spatial match
        if x1.shape[2:] != x2.shape[2:]:
            x2 = F.interpolate(x2, size=x1.shape[2:], mode='bilinear', align_corners=False)
        x = torch.cat([x2, x1], dim=1)
        return self.res_block(x)

class OutConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(OutConv, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=1)

    def forward(self, x):
        return self.conv(x)

class UNetHybridResidual(nn.Module):
    def __init__(self, in_channels=1, out_channels=1, depth=3, start_filters=64, bilinear=False):
        super(UNetHybridResidual, self).__init__()
        self.depth = depth

        self.inc = nn.Sequential(
            nn.Conv2d(in_channels, start_filters, kernel_size=3, padding=1),
            nn.GELU(),
            ResidualBlock(start_filters)
        )

        self.down_layers = nn.ModuleList()
        self.up_layers = nn.ModuleList()
        filters = start_filters
        for _ in range(depth):
            self.down_layers.append(Down(filters, filters * 2))
            filters *= 2

        for _ in range(depth):
            self.up_layers.append(Up(filters, filters // 2, bilinear=bilinear))
            filters //= 2

        self.outc = OutConv(filters, out_channels)

    def forward(self, x):
        x_skips = []

        # Encoder
        x = self.inc(x)
        x_skips.append(x)
        for down in self.down_layers:
            x = down(x)
            x_skips.append(x)

        # Decoder
        x_skips = x_skips[::-1]
        for i, up in enumerate(self.up_layers):
            x = up(x, x_skips[i + 1])

        return self.outc(x)

# %% [markdown]
# ___
# ### custom loss function and function to execute training

# %%
from pytorch_msssim import ssim

class CustomLoss(nn.Module):
    def __init__(self, alpha=0.84):  # alpha controls MSE vs SSIM weight
        super(CustomLoss, self).__init__()
        self.alpha = alpha

    def forward(self, pred, target):
        mse_loss = F.mse_loss(pred, target)
        ssim_loss = 1 - ssim(pred, target, data_range=1.0, size_average=True)
        return self.alpha * mse_loss + (1 - self.alpha) * ssim_loss

    
def train_model(model, opt, criterion, train_loader, num_epoch):
    avg_train_losses = []

    for epoch in range(num_epoch):  # Loop over the dataset multiple times
        model.train()
        total_train_loss = 0

        for i, (x_tr_batch, y_tr_batch) in enumerate(train_loader):  # Loop over mini-batches
            x_tr_batch, y_tr_batch = x_tr_batch.to(device), y_tr_batch.to(device)

            # Upsample low-resolution input to 256x256
            x_tr_batch = torch.nn.functional.interpolate(x_tr_batch, scale_factor=2, mode='bicubic', align_corners=False)

            opt.zero_grad()  # Delete previous gradients
            y_hat_tr_batch = model(x_tr_batch)  # Forward pass
            loss = criterion(y_hat_tr_batch, y_tr_batch)  # Compute loss
            loss.backward()  # Backward pass
            opt.step()  # Update weights
            total_train_loss += loss.item()  # Accumulate loss
      

            if (i + 1) % 10 == 0:
                print(f'Epoch {epoch+1}, Iteration {i+1}, Loss: {loss.item():.6f}')

        avg_train_loss = total_train_loss / len(train_loader)  # Compute average loss
        avg_train_losses.append(avg_train_loss)  # Store average loss
    torch.cuda.empty_cache() # see if emptying cache helps with oom

    # Plot training loss
    fig, ax = plt.subplots(figsize=(8, 5))
    ax.plot(range(1, num_epoch + 1), avg_train_losses, label='training loss')
    ax.set_xlabel('epochs')
    ax.set_ylabel('SSIM+L1 loss')
    ax.set_yscale('log')  # Log scale for better visualization
    ax.set_title('training loss')
    ax.grid(True)
    ax.legend()
    plt.show()

# %% [markdown]
# ___
# ### Now, let us define hyperparameters and train the network.
#
# #### Note, in addition to the parameters that controls the network architecture or the training process, you need to select/initialize (i) a data loader, (ii) a model, (iii) an optimizer, and (iv) a loss function.

# %%
batch_size = 5  # Number of complete images in each batch
lr = 1e-3  # Learning rate
num_epoch = 100  # Epochs

# Model, criterion, and optimizer
train_loader = create_loader(train_dataset, batch_size)
model = UNetHybridResidual(in_channels=1, out_channels=1).to(device)  # Create the model
opt = optim.Adam(model.parameters(), lr=lr)  # Pick an optimizer
#criterion = SSIM_L1_Loss(alpha=0.5)  # Pick a loss function (MSE or SSIM+L1)
criterion= CustomLoss(alpha=0.84)  # Initialize custom loss function`

# Train the model
train_model(model, opt, criterion, train_loader, num_epoch)
# Out:
# Epoch 1, Iteration 10, Loss: 0.211067
# Epoch 1, Iteration 20, Loss: 0.189655
# Epoch 1, Iteration 30, Loss: 0.176992
# Epoch 1, Iteration 40, Loss: 0.152808
# Epoch 2, Iteration 10, Loss: 0.132568
# Epoch 2, Iteration 20, Loss: 0.124738
# Epoch 2, Iteration 30, Loss: 0.132484
# Epoch 2, Iteration 40, Loss: 0.116496
# Epoch 3, Iteration 10, Loss: 0.141323
# Epoch 3, Iteration 20, Loss: 0.094547
# Epoch 3, Iteration 30, Loss: 0.076656
# Epoch 3, Iteration 40, Loss: 0.094716
# Epoch 4, Iteration 10, Loss: 0.090572
# Epoch 4, Iteration 20, Loss: 0.120833
# Epoch 4, Iteration 30, Loss: 0.119902
# Epoch 4, Iteration 40, Loss: 0.078544
# Epoch 5, Iteration 10, Loss: 0.064737
# Epoch 5, Iteration 20, Loss: 0.065770
# Epoch 5, Iteration 30, Loss: 0.039775
# Epoch 5, Iteration 40, Loss: 0.107918
# Epoch 6, Iteration 10, Loss: 0.038005
# Epoch 6, Iteration 20, Loss: 0.028063
# Epoch 6, Iteration 30, Loss: 0.029663
# Epoch 6, Iteration 40, Loss: 0.045797
# Epoch 7, Iteration 10, Loss: 0.036194
# Epoch 7, Iteration 20, Loss: 0.024487
# Epoch 7, Iteration 30, Loss: 0.042865
# Epoch 7, Iteration 40, Loss: 0.023113
# Epoch 8, Iteration 10, Loss: 0.062524
# Epoch 8, Iteration 20, Loss: 0.061277
# Epoch 8, Iteration 30, Loss: 0.045433
# Epoch 8, Iteration 40, Loss: 0.037067
# Epoch 9, Iteration 10, Loss: 0.045146
# Epoch 9, Iteration 20, Loss: 0.045647
# Epoch 9, Iteration 30, Loss: 0.030718
# Epoch 9, Iteration 40, Loss: 0.030669
# Epoch 10, Iteration 10, Loss: 0.029031
# Epoch 10, Iteration 20, Loss: 0.034751
# Epoch 10, Iteration 30, Loss: 0.022288
# Epoch 10, Iteration 40, Loss: 0.030072
# Epoch 11, Iteration 10, Loss: 0.021212
# Epoch 11, Iteration 20, Loss: 0.018475
# Epoch 11, Iteration 30, Loss: 0.043808
# Epoch 11, Iteration 40, Loss: 0.020361
# Epoch 12, Iteration 10, Loss: 0.037503
# Epoch 12, Iteration 20, Loss: 0.031560
# Epoch 12, Iteration 30, Loss: 0.025193
# Epoch 12, Iteration 40, Loss: 0.019273
# Epoch 13, Iteration 10, Loss: 0.021457
# Epoch 13, Iteration 20, Loss: 0.024731
# Epoch 13, Iteration 30, Loss: 0.020962
# Epoch 13, Iteration 40, Loss: 0.017547
# Epoch 14, Iteration 10, Loss: 0.030219
# Epoch 14, Iteration 20, Loss: 0.020247
# Epoch 14, Iteration 30, Loss: 0.019271
# Epoch 14, Iteration 40, Loss: 0.015698
# Epoch 15, Iteration 10, Loss: 0.017086
# Epoch 15, Iteration 20, Loss: 0.023581
# Epoch 15, Iteration 30, Loss: 0.018567
# Epoch 15, Iteration 40, Loss: 0.019908
# Epoch 16, Iteration 10, Loss: 0.026439
# Epoch 16, Iteration 20, Loss: 0.017649
# Epoch 16, Iteration 30, Loss: 0.037084
# Epoch 16, Iteration 40, Loss: 0.024134
# Epoch 17, Iteration 10, Loss: 0.015885
# Epoch 17, Iteration 20, Loss: 0.019522
# Epoch 17, Iteration 30, Loss: 0.029117
# Epoch 17, Iteration 40, Loss: 0.025325
# Epoch 18, Iteration 10, Loss: 0.030355
# Epoch 18, Iteration 20, Loss: 0.021290
# Epoch 18, Iteration 30, Loss: 0.020351
# Epoch 18, Iteration 40, Loss: 0.025126
# Epoch 19, Iteration 10, Loss: 0.015693
# Epoch 19, Iteration 20, Loss: 0.020261
# Epoch 19, Iteration 30, Loss: 0.014041
# Epoch 19, Iteration 40, Loss: 0.015735
# Epoch 20, Iteration 10, Loss: 0.018390
# Epoch 20, Iteration 20, Loss: 0.018078
# Epoch 20, Iteration 30, Loss: 0.016244
# Epoch 20, Iteration 40, Loss: 0.015151
# Epoch 21, Iteration 10, Loss: 0.012835
# Epoch 21, Iteration 20, Loss: 0.014125
# Epoch 21, Iteration 30, Loss: 0.017785
# Epoch 21, Iteration 40, Loss: 0.015527
# Epoch 22, Iteration 10, Loss: 0.015147
# Epoch 22, Iteration 20, Loss: 0.014542
# Epoch 22, Iteration 30, Loss: 0.019528
# Epoch 22, Iteration 40, Loss: 0.021621
# Epoch 23, Iteration 10, Loss: 0.014069
# Epoch 23, Iteration 20, Loss: 0.015183
# Epoch 23, Iteration 30, Loss: 0.014660
# Epoch 23, Iteration 40, Loss: 0.011944
# Epoch 24, Iteration 10, Loss: 0.020185
# Epoch 24, Iteration 20, Loss: 0.012955
# Epoch 24, Iteration 30, Loss: 0.016332
# Epoch 24, Iteration 40, Loss: 0.011839
# Epoch 25, Iteration 10, Loss: 0.014953
# Epoch 25, Iteration 20, Loss: 0.013657
# Epoch 25, Iteration 30, Loss: 0.015408
# Epoch 25, Iteration 40, Loss: 0.013108
# Epoch 26, Iteration 10, Loss: 0.012227
# Epoch 26, Iteration 20, Loss: 0.015297
# Epoch 26, Iteration 30, Loss: 0.014157
# Epoch 26, Iteration 40, Loss: 0.014102
# Epoch 27, Iteration 10, Loss: 0.015071
# Epoch 27, Iteration 20, Loss: 0.012913
# Epoch 27, Iteration 30, Loss: 0.013519
# Epoch 27, Iteration 40, Loss: 0.013523
# Epoch 28, Iteration 10, Loss: 0.013619
# Epoch 28, Iteration 20, Loss: 0.013112
# Epoch 28, Iteration 30, Loss: 0.014058
# Epoch 28, Iteration 40, Loss: 0.013753
# Epoch 29, Iteration 10, Loss: 0.013421
# Epoch 29, Iteration 20, Loss: 0.012928
# Epoch 29, Iteration 30, Loss: 0.013018
# Epoch 29, Iteration 40, Loss: 0.012147
# Epoch 30, Iteration 10, Loss: 0.012696
# Epoch 30, Iteration 20, Loss: 0.013604
# Epoch 30, Iteration 30, Loss: 0.013410
# Epoch 30, Iteration 40, Loss: 0.012738
# Epoch 31, Iteration 10, Loss: 0.013334
# Epoch 31, Iteration 20, Loss: 0.013502
# Epoch 31, Iteration 30, Loss: 0.021502
# Epoch 31, Iteration 40, Loss: 0.013795
# Epoch 32, Iteration 10, Loss: 0.013330
# Epoch 32, Iteration 20, Loss: 0.014605
# Epoch 32, Iteration 30, Loss: 0.019382
# Epoch 32, Iteration 40, Loss: 0.019374
# Epoch 33, Iteration 10, Loss: 0.016530
# Epoch 33, Iteration 20, Loss: 0.013997
# Epoch 33, Iteration 30, Loss: 0.014005
# Epoch 33, Iteration 40, Loss: 0.013408
# Epoch 34, Iteration 10, Loss: 0.011414
# Epoch 34, Iteration 20, Loss: 0.013712
# Epoch 34, Iteration 30, Loss: 0.016246
# Epoch 34, Iteration 40, Loss: 0.014496
# Epoch 35, Iteration 10, Loss: 0.013343
# Epoch 35, Iteration 20, Loss: 0.012766
# Epoch 35, Iteration 30, Loss: 0.014265
# Epoch 35, Iteration 40, Loss: 0.013542
# Epoch 36, Iteration 10, Loss: 0.011709
# Epoch 36, Iteration 20, Loss: 0.011985
# Epoch 36, Iteration 30, Loss: 0.012794
# Epoch 36, Iteration 40, Loss: 0.011669
# Epoch 37, Iteration 10, Loss: 0.012194
# Epoch 37, Iteration 20, Loss: 0.013286
# Epoch 37, Iteration 30, Loss: 0.012789
# Epoch 37, Iteration 40, Loss: 0.012293
# Epoch 38, Iteration 10, Loss: 0.010827
# Epoch 38, Iteration 20, Loss: 0.014024
# Epoch 38, Iteration 30, Loss: 0.011004
# Epoch 38, Iteration 40, Loss: 0.014186
# Epoch 39, Iteration 10, Loss: 0.013451
# Epoch 39, Iteration 20, Loss: 0.010582
# Epoch 39, Iteration 30, Loss: 0.012741
# Epoch 39, Iteration 40, Loss: 0.011456
# Epoch 40, Iteration 10, Loss: 0.011370
# Epoch 40, Iteration 20, Loss: 0.011934
# Epoch 40, Iteration 30, Loss: 0.011242
# Epoch 40, Iteration 40, Loss: 0.020104
# Epoch 41, Iteration 10, Loss: 0.014665
# Epoch 41, Iteration 20, Loss: 0.014945
# Epoch 41, Iteration 30, Loss: 0.012764
# Epoch 41, Iteration 40, Loss: 0.012213
# Epoch 42, Iteration 10, Loss: 0.012393
# Epoch 42, Iteration 20, Loss: 0.012640
# Epoch 42, Iteration 30, Loss: 0.012025
# Epoch 42, Iteration 40, Loss: 0.012194
# Epoch 43, Iteration 10, Loss: 0.012774
# Epoch 43, Iteration 20, Loss: 0.011191
# Epoch 43, Iteration 30, Loss: 0.014173
# Epoch 43, Iteration 40, Loss: 0.015186
# Epoch 44, Iteration 10, Loss: 0.012907
# Epoch 44, Iteration 20, Loss: 0.014834
# Epoch 44, Iteration 30, Loss: 0.013791
# Epoch 44, Iteration 40, Loss: 0.012709
# Epoch 45, Iteration 10, Loss: 0.011332
# Epoch 45, Iteration 20, Loss: 0.013646
# Epoch 45, Iteration 30, Loss: 0.018639
# Epoch 45, Iteration 40, Loss: 0.015423
# Epoch 46, Iteration 10, Loss: 0.017828
# Epoch 46, Iteration 20, Loss: 0.013876
# Epoch 46, Iteration 30, Loss: 0.013506
# Epoch 46, Iteration 40, Loss: 0.013483
# Epoch 47, Iteration 10, Loss: 0.011752
# Epoch 47, Iteration 20, Loss: 0.012689
# Epoch 47, Iteration 30, Loss: 0.012128
# Epoch 47, Iteration 40, Loss: 0.011883
# Epoch 48, Iteration 10, Loss: 0.010933
# Epoch 48, Iteration 20, Loss: 0.013263
# Epoch 48, Iteration 30, Loss: 0.012975
# Epoch 48, Iteration 40, Loss: 0.011620
# Epoch 49, Iteration 10, Loss: 0.012482
# Epoch 49, Iteration 20, Loss: 0.011529
# Epoch 49, Iteration 30, Loss: 0.011080
# Epoch 49, Iteration 40, Loss: 0.011992
# Epoch 50, Iteration 10, Loss: 0.011208
# Epoch 50, Iteration 20, Loss: 0.012168
# Epoch 50, Iteration 30, Loss: 0.011326
# Epoch 50, Iteration 40, Loss: 0.011841
# Epoch 51, Iteration 10, Loss: 0.011434
# Epoch 51, Iteration 20, Loss: 0.011504
# Epoch 51, Iteration 30, Loss: 0.010307
# Epoch 51, Iteration 40, Loss: 0.012590
# Epoch 52, Iteration 10, Loss: 0.010375
# Epoch 52, Iteration 20, Loss: 0.010293
# Epoch 52, Iteration 30, Loss: 0.011491
# Epoch 52, Iteration 40, Loss: 0.013185
# Epoch 53, Iteration 10, Loss: 0.012313
# Epoch 53, Iteration 20, Loss: 0.011060
# Epoch 53, Iteration 30, Loss: 0.010915
# Epoch 53, Iteration 40, Loss: 0.011401
# Epoch 54, Iteration 10, Loss: 0.011711
# Epoch 54, Iteration 20, Loss: 0.011867
# Epoch 54, Iteration 30, Loss: 0.013097
# Epoch 54, Iteration 40, Loss: 0.013623
# Epoch 55, Iteration 10, Loss: 0.010755
# Epoch 55, Iteration 20, Loss: 0.012680
# Epoch 55, Iteration 30, Loss: 0.016111
# Epoch 55, Iteration 40, Loss: 0.011224
# Epoch 56, Iteration 10, Loss: 0.010297
# Epoch 56, Iteration 20, Loss: 0.011080
# Epoch 56, Iteration 30, Loss: 0.013553
# Epoch 56, Iteration 40, Loss: 0.011394
# Epoch 57, Iteration 10, Loss: 0.015246
# Epoch 57, Iteration 20, Loss: 0.017485
# Epoch 57, Iteration 30, Loss: 0.013258
# Epoch 57, Iteration 40, Loss: 0.013826
# Epoch 58, Iteration 10, Loss: 0.012285
# Epoch 58, Iteration 20, Loss: 0.013309
# Epoch 58, Iteration 30, Loss: 0.013161
# Epoch 58, Iteration 40, Loss: 0.012504
# Epoch 59, Iteration 10, Loss: 0.016428
# Epoch 59, Iteration 20, Loss: 0.013696
# Epoch 59, Iteration 30, Loss: 0.014269
# Epoch 59, Iteration 40, Loss: 0.010369
# Epoch 60, Iteration 10, Loss: 0.011190
# Epoch 60, Iteration 20, Loss: 0.011975
# Epoch 60, Iteration 30, Loss: 0.013243
# Epoch 60, Iteration 40, Loss: 0.011325
# Epoch 61, Iteration 10, Loss: 0.010682
# Epoch 61, Iteration 20, Loss: 0.011256
# Epoch 61, Iteration 30, Loss: 0.010421
# Epoch 61, Iteration 40, Loss: 0.011060
# Epoch 62, Iteration 10, Loss: 0.011230
# Epoch 62, Iteration 20, Loss: 0.011315
# Epoch 62, Iteration 30, Loss: 0.010171
# Epoch 62, Iteration 40, Loss: 0.010193
# Epoch 63, Iteration 10, Loss: 0.010210
# Epoch 63, Iteration 20, Loss: 0.011716
# Epoch 63, Iteration 30, Loss: 0.014035
# Epoch 63, Iteration 40, Loss: 0.012051
# Epoch 64, Iteration 10, Loss: 0.011661
# Epoch 64, Iteration 20, Loss: 0.011500
# Epoch 64, Iteration 30, Loss: 0.010938
# Epoch 64, Iteration 40, Loss: 0.011571
# Epoch 65, Iteration 10, Loss: 0.009890
# Epoch 65, Iteration 20, Loss: 0.011061
# Epoch 65, Iteration 30, Loss: 0.009916
# Epoch 65, Iteration 40, Loss: 0.010834
# Epoch 66, Iteration 10, Loss: 0.010336
# Epoch 66, Iteration 20, Loss: 0.009645
# Epoch 66, Iteration 30, Loss: 0.011969
# Epoch 66, Iteration 40, Loss: 0.010637
# Epoch 67, Iteration 10, Loss: 0.010481
# Epoch 67, Iteration 20, Loss: 0.012023
# Epoch 67, Iteration 30, Loss: 0.010644
# Epoch 67, Iteration 40, Loss: 0.010456
# Epoch 68, Iteration 10, Loss: 0.010877
# Epoch 68, Iteration 20, Loss: 0.011546
# Epoch 68, Iteration 30, Loss: 0.010844
# Epoch 68, Iteration 40, Loss: 0.009955
# Epoch 69, Iteration 10, Loss: 0.011372
# Epoch 69, Iteration 20, Loss: 0.012295
# Epoch 69, Iteration 30, Loss: 0.013719
# Epoch 69, Iteration 40, Loss: 0.010241
# Epoch 70, Iteration 10, Loss: 0.011393
# Epoch 70, Iteration 20, Loss: 0.010912
# Epoch 70, Iteration 30, Loss: 0.012822
# Epoch 70, Iteration 40, Loss: 0.010026
# Epoch 71, Iteration 10, Loss: 0.010759
# Epoch 71, Iteration 20, Loss: 0.010892
# Epoch 71, Iteration 30, Loss: 0.010527
# Epoch 71, Iteration 40, Loss: 0.009412
# Epoch 72, Iteration 10, Loss: 0.011265
# Epoch 72, Iteration 20, Loss: 0.009984
# Epoch 72, Iteration 30, Loss: 0.010413
# Epoch 72, Iteration 40, Loss: 0.010170
# Epoch 73, Iteration 10, Loss: 0.010820
# Epoch 73, Iteration 20, Loss: 0.011041
# Epoch 73, Iteration 30, Loss: 0.010239
# Epoch 73, Iteration 40, Loss: 0.009696
# Epoch 74, Iteration 10, Loss: 0.012096
# Epoch 74, Iteration 20, Loss: 0.011785
# Epoch 74, Iteration 30, Loss: 0.015173
# Epoch 74, Iteration 40, Loss: 0.011973
# Epoch 75, Iteration 10, Loss: 0.009790
# Epoch 75, Iteration 20, Loss: 0.011002
# Epoch 75, Iteration 30, Loss: 0.009168
# Epoch 75, Iteration 40, Loss: 0.010467
# Epoch 76, Iteration 10, Loss: 0.009833
# Epoch 76, Iteration 20, Loss: 0.009810
# Epoch 76, Iteration 30, Loss: 0.011924
# Epoch 76, Iteration 40, Loss: 0.010257
# Epoch 77, Iteration 10, Loss: 0.010299
# Epoch 77, Iteration 20, Loss: 0.010041
# Epoch 77, Iteration 30, Loss: 0.011592
# Epoch 77, Iteration 40, Loss: 0.010969
# Epoch 78, Iteration 10, Loss: 0.011954
# Epoch 78, Iteration 20, Loss: 0.014938
# Epoch 78, Iteration 30, Loss: 0.011531
# Epoch 78, Iteration 40, Loss: 0.047290
# Epoch 79, Iteration 10, Loss: 0.049022
# Epoch 79, Iteration 20, Loss: 0.022278
# Epoch 79, Iteration 30, Loss: 0.022832
# Epoch 79, Iteration 40, Loss: 0.034353
# Epoch 80, Iteration 10, Loss: 0.023652
# Epoch 80, Iteration 20, Loss: 0.023468
# Epoch 80, Iteration 30, Loss: 0.046421
# Epoch 80, Iteration 40, Loss: 0.023038
# Epoch 81, Iteration 10, Loss: 0.026216
# Epoch 81, Iteration 20, Loss: 0.017848
# Epoch 81, Iteration 30, Loss: 0.019755
# Epoch 81, Iteration 40, Loss: 0.013799
# Epoch 82, Iteration 10, Loss: 0.013625
# Epoch 82, Iteration 20, Loss: 0.017722
# Epoch 82, Iteration 30, Loss: 0.028122
# Epoch 82, Iteration 40, Loss: 0.017476
# Epoch 83, Iteration 10, Loss: 0.014281
# Epoch 83, Iteration 20, Loss: 0.013784
# Epoch 83, Iteration 30, Loss: 0.011193
# Epoch 83, Iteration 40, Loss: 0.011865
# Epoch 84, Iteration 10, Loss: 0.015101
# Epoch 84, Iteration 20, Loss: 0.011564
# Epoch 84, Iteration 30, Loss: 0.012230
# Epoch 84, Iteration 40, Loss: 0.012981
# Epoch 85, Iteration 10, Loss: 0.012281
# Epoch 85, Iteration 20, Loss: 0.011668
# Epoch 85, Iteration 30, Loss: 0.012155
# Epoch 85, Iteration 40, Loss: 0.011120
# Epoch 86, Iteration 10, Loss: 0.012330
# Epoch 86, Iteration 20, Loss: 0.014284
# Epoch 86, Iteration 30, Loss: 0.014210
# Epoch 86, Iteration 40, Loss: 0.012527
# Epoch 87, Iteration 10, Loss: 0.015690
# Epoch 87, Iteration 20, Loss: 0.012390
# Epoch 87, Iteration 30, Loss: 0.013814
# Epoch 87, Iteration 40, Loss: 0.010864
# Epoch 88, Iteration 10, Loss: 0.012223
# Epoch 88, Iteration 20, Loss: 0.028774
# Epoch 88, Iteration 30, Loss: 0.015609
# Epoch 88, Iteration 40, Loss: 0.015054
# Epoch 89, Iteration 10, Loss: 0.022392
# Epoch 89, Iteration 20, Loss: 0.015630
# Epoch 89, Iteration 30, Loss: 0.014013
# Epoch 89, Iteration 40, Loss: 0.015990
# Epoch 90, Iteration 10, Loss: 0.011459
# Epoch 90, Iteration 20, Loss: 0.012026
# Epoch 90, Iteration 30, Loss: 0.011403
# Epoch 90, Iteration 40, Loss: 0.010745
# Epoch 91, Iteration 10, Loss: 0.010614
# Epoch 91, Iteration 20, Loss: 0.011069
# Epoch 91, Iteration 30, Loss: 0.011531
# Epoch 91, Iteration 40, Loss: 0.010655
# Epoch 92, Iteration 10, Loss: 0.011424
# Epoch 92, Iteration 20, Loss: 0.011901
# Epoch 92, Iteration 30, Loss: 0.012027
# Epoch 92, Iteration 40, Loss: 0.012368
# Epoch 93, Iteration 10, Loss: 0.012493
# Epoch 93, Iteration 20, Loss: 0.011780
# Epoch 93, Iteration 30, Loss: 0.010559
# Epoch 93, Iteration 40, Loss: 0.011761
# Epoch 94, Iteration 10, Loss: 0.012101
# Epoch 94, Iteration 20, Loss: 0.009949
# Epoch 94, Iteration 30, Loss: 0.011354
# Epoch 94, Iteration 40, Loss: 0.011210
# Epoch 95, Iteration 10, Loss: 0.011244
# Epoch 95, Iteration 20, Loss: 0.012907
# Epoch 95, Iteration 30, Loss: 0.010942
# Epoch 95, Iteration 40, Loss: 0.010623
# Epoch 96, Iteration 10, Loss: 0.010360
# Epoch 96, Iteration 20, Loss: 0.010145
# Epoch 96, Iteration 30, Loss: 0.009566
# Epoch 96, Iteration 40, Loss: 0.012163
# Epoch 97, Iteration 10, Loss: 0.010236
# Epoch 97, Iteration 20, Loss: 0.010309
# Epoch 97, Iteration 30, Loss: 0.011039
# Epoch 97, Iteration 40, Loss: 0.009254
# Epoch 98, Iteration 10, Loss: 0.012110
# Epoch 98, Iteration 20, Loss: 0.011793
# Epoch 98, Iteration 30, Loss: 0.010765
# Epoch 98, Iteration 40, Loss: 0.012136
# Epoch 99, Iteration 10, Loss: 0.013342
# Epoch 99, Iteration 20, Loss: 0.015499
# Epoch 99, Iteration 30, Loss: 0.012985
# Epoch 99, Iteration 40, Loss: 0.011242
# Epoch 100, Iteration 10, Loss: 0.013538
# Epoch 100, Iteration 20, Loss: 0.012204
# Epoch 100, Iteration 30, Loss: 0.015252
# Epoch 100, Iteration 40, Loss: 0.012978

# %% [markdown]
# ___
# ### Apply it one of the validation image

# %%
# Create the dataset for validation images
val_dataset = TIFFDataset('data/val/high-res', 'data/val/low-res', transform=transform)

# Load one (low-res, high-res) image pair from validation dataset and move it to the dedvice
val_low_res, val_high_res = val_dataset[1]  # Input (128x128), Ground truth (256x256)
val_low_res, val_high_res = val_low_res.to(device), val_high_res.to(device)

# Upsample low-resolution image to 256x256 for both model input and error visualization
val_low_res_interpolated = torch.nn.functional.interpolate(val_low_res.unsqueeze(0), scale_factor=2, mode='bicubic', align_corners=False).squeeze(0)

# Apply the trained model to super-resolve the interpolated low-res image
val_super_res = model(val_low_res_interpolated.unsqueeze(0)).detach().squeeze(0)  # Remove batch dimension

# Convert tensors to numpy for visualization
val_low_res_np = val_low_res_interpolated.squeeze().cpu().numpy()  # Use the interpolated version for error maps
val_high_res_np = val_high_res.squeeze().cpu().numpy()
val_super_res_np = val_super_res.squeeze().cpu().numpy()

# Plot an example image and error maps
fig, ax = plt.subplots(2, 3, figsize=(10, 7))

# Plot images
ax[0, 0].imshow(val_high_res_np, cmap='gray', vmin=0, vmax=1)
ax[0, 0].set_title('ground truth (high-res)')
ax[0, 0].axis('off')

ax[0, 1].imshow(val_low_res_np, cmap='gray', vmin=0, vmax=1)
ax[0, 1].set_title('interpolated low-res image')
ax[0, 1].axis('off')

ax[0, 2].imshow(val_super_res_np, cmap='gray', vmin=0, vmax=1)
ax[0, 2].set_title('super-resolved image')
ax[0, 2].axis('off')

# Error maps
ax[1, 0].imshow(5 * np.abs(val_high_res_np - val_high_res_np), cmap='gray', vmin=0, vmax=1)
ax[1, 0].axis('off')
ax[1, 0].text(0.02, 0.98, r'$\times 5$', transform=ax[1, 0].transAxes, fontsize=14, va='top', ha='left', color='white')

ax[1, 1].imshow(5 * np.abs(val_high_res_np - val_low_res_np), cmap='gray', vmin=0, vmax=1)
ax[1, 1].axis('off')
ax[1, 1].text(0.02, 0.98, r'$\times 5$', transform=ax[1, 1].transAxes, fontsize=14, va='top', ha='left', color='white')

ax[1, 2].imshow(5 * np.abs(val_high_res_np - val_super_res_np), cmap='gray', vmin=0, vmax=1)
ax[1, 2].axis('off')
ax[1, 2].text(0.02, 0.98, r'$\times 5$', transform=ax[1, 2].transAxes, fontsize=14, va='top', ha='left', color='white')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Compute PSNR and SSIM over the entire validation dataset

# %%
# Initialize metrics
psnr_metric = PeakSignalNoiseRatio().to(device) # rewrite
ssim_metric = StructuralSimilarityIndexMeasure(data_range=1.0).to(device)

# Accumulators
total_psnr_interpolated = 0
total_psnr_super_resolved = 0
total_ssim_interpolated = 0
total_ssim_super_resolved = 0
num_samples = len(val_dataset)

# Loop over validation set
for i in range(num_samples):
    val_low_res, val_high_res = val_dataset[i]
    val_low_res, val_high_res = val_low_res.to(device), val_high_res.to(device)

    # Compute data range dynamically
    data_range = val_high_res.max() - val_high_res.min()
    ssim_metric.data_range = data_range

    # Upsample low-res image
    val_low_res_up = torch.nn.functional.interpolate(val_low_res.unsqueeze(0), scale_factor=2, mode='bicubic', align_corners=False)
    val_high_res = val_high_res.unsqueeze(0)  # Add batch dim
    val_super_res = model(val_low_res_up).detach()

    # PSNR
    psnr_interp = psnr_metric(val_low_res_up, val_high_res).item()
    psnr_sr = psnr_metric(val_super_res, val_high_res).item()

    # SSIM (data_range is now set in metric initialization)
    ssim_interp = ssim_metric(val_low_res_up, val_high_res).item()
    ssim_sr = ssim_metric(val_super_res, val_high_res).item()

    # Accumulate
    total_psnr_interpolated += psnr_interp
    total_psnr_super_resolved += psnr_sr
    total_ssim_interpolated += ssim_interp
    total_ssim_super_resolved += ssim_sr

# Averages
avg_psnr_interp = total_psnr_interpolated / num_samples
avg_psnr_sr = total_psnr_super_resolved / num_samples
avg_ssim_interp = total_ssim_interpolated / num_samples
avg_ssim_sr = total_ssim_super_resolved / num_samples

# Print results
print(f'Average PSNR (interpolated): {avg_psnr_interp:.2f} dB')
print(f'Average PSNR (super-resolved): {avg_psnr_sr:.2f} dB')
print(f'Average SSIM (interpolated): {avg_ssim_interp:.4f}')
print(f'Average SSIM (super-resolved): {avg_ssim_sr:.4f}')
#print(avg_psnr_sr+40*avg_ssim_sr)
#print(f'Average SSIM (super-resolved): {avg_ssim_sr:.4f}')
# Out:
# Average PSNR (interpolated): 30.81 dB
# Average PSNR (super-resolved): 31.52 dB
# Average SSIM (interpolated): 0.9056
# Average SSIM (super-resolved): 0.8870
# 66.99993510246277
