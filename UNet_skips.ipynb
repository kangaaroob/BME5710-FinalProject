# %% [markdown]
# ___
# # **Starter code for BME 5710 project**
# ## Instructor -- Rizwan Ahmad (ahmad.46@osu.edu)
# ## BME5710 -- Spring 2025

# %% [markdown]
# ___
# ### Import libraries and sub-libraries.

# %%
import os
import numpy as np
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import matplotlib.pyplot as plt
from torchvision.transforms import functional as TF
import torch.nn.functional as F
from torchmetrics.image.psnr import PeakSignalNoiseRatio
from torchmetrics.image.ssim import StructuralSimilarityIndexMeasure
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("GPU name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# You can install torchmeterics using: pip install torchmetrics
# Out:
# PyTorch version: 2.5.1+cu121
# CUDA available: True
# GPU name: NVIDIA GeForce RTX 3050 Ti Laptop GPU

# %% [markdown]
# ___
# ### Calling a custom code to change the default font for figures to `Computer Modern`. (Optional)

# %%
#from fontsetting import font_cmu
#plt = font_cmu(plt)
# Disable LaTeX
#plt.rcParams['text.usetex'] = False

# %% [markdown]
# ___
# ### Check the hardware that is at your disposal

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Device available:', device)
# Out:
# Device available: cuda

# %% [markdown]
# ___
# ### Read training data from `data/train/hig-res` and `data/train/low-res`

# %%
# Loading TIFF images for Super-resolution
class TIFFDataset(Dataset):
    def __init__(self, high_res_dir, low_res_dir, transform=None):
        self.high_res_dir = high_res_dir
        self.low_res_dir = low_res_dir
        self.transform = transform
        self.filenames = sorted([f for f in os.listdir(high_res_dir) if f.endswith('.tif')])
    
    # Get the number of samples in the dataset
    def __len__(self):
        return len(self.filenames)

    # Get the sample at the given index
    def __getitem__(self, idx):
        high_res_path = os.path.join(self.high_res_dir, self.filenames[idx])
        low_res_path = os.path.join(self.low_res_dir, self.filenames[idx])

        # Load images
        high_res = Image.open(high_res_path)
        low_res = Image.open(low_res_path)

        # Resize low-res to 128x128 (ensuring correct input size)
        low_res = low_res.resize((128, 128), Image.BICUBIC)

        # Apply transformations
        if self.transform:
            high_res = self.transform(high_res)
            low_res = self.transform(low_res)

        return low_res, high_res  # Returning input-output pairs

# Define a transform to convert images to PyTorch tensors
transform = transforms.Compose([
    transforms.ToTensor()
])

# Create the dataset for training images
train_dataset = TIFFDataset('data/train/high-res', 'data/train/low-res', transform=transform)

# Function to create data loader
def create_loader(dataset, batch_size):
    torch.manual_seed(0)  # For reproducibility
    return DataLoader(dataset, batch_size=batch_size, shuffle=True)

# Print dataset size
dataset_size = len(train_dataset)
print('Number of images in the dataset:', dataset_size)
# Out:
# Number of images in the dataset: 240

# %% [markdown]
# ___
# ### Define a super-resolution network
#
# #### Here, I have defined a trivial network, which has only two layers and no activation function. We are essentially doing linear filtering.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class ResidualBlock(nn.Module):
    def __init__(self, channels):
        super(ResidualBlock, self).__init__()
        self.block = nn.Sequential(
            nn.Conv2d(channels, channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(channels, channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(channels)
        )

    def forward(self, x):
        return x + self.block(x)

class UNetSkips(nn.Module):
    def __init__(self, in_channels=1, out_channels=1):
        super(UNetSkips, self).__init__()

        # Encoder
        self.down_conv1 = nn.Sequential(
            nn.Conv2d(in_channels, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            ResidualBlock(64),
            nn.Dropout(0.1),
            nn.Conv2d(64, 64, kernel_size=3, stride=2, padding=1)
        )

        # Bottleneck
        self.bottleneck = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Dropout(0.1),
            ResidualBlock(128)
        )

        # Upsample
        self.upsample = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)

        # Learnable skip connection
        self.skip_conv = nn.Conv2d(64, 64, kernel_size=1)

        # Decoder (simplified)
        self.decoder = nn.Sequential(
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, out_channels, kernel_size=3, padding=1)
        )

    def forward(self, x):
        x1 = self.down_conv1(x)   # Encoder
        x2 = self.bottleneck(x1)
        x3 = self.upsample(x2)    # Upsample

        # Match size
        if x3.shape[2:] != x1.shape[2:]:
            x1 = F.interpolate(x1, size=x3.shape[2:], mode='bilinear', align_corners=False)

        x1_proj = self.skip_conv(x1)  # Learnable skip
        x_cat = torch.cat([x3, x1_proj], dim=1)  # Merge

        out = self.decoder(x_cat)
        return out

# %% [markdown]
# ___
# ### Create a function to execute training. Note, we will call this function later.

# %%
def train_model(model, opt, criterion, train_loader, num_epoch):
    avg_train_losses = []

    for epoch in range(num_epoch):  # Loop over the dataset multiple times
        model.train()
        total_train_loss = 0

        for i, (x_tr_batch, y_tr_batch) in enumerate(train_loader):  # Loop over mini-batches
            x_tr_batch, y_tr_batch = x_tr_batch.to(device), y_tr_batch.to(device)

            # Upsample low-resolution input to 256x256
            x_tr_batch = torch.nn.functional.interpolate(x_tr_batch, scale_factor=2, mode='bicubic', align_corners=False)

            opt.zero_grad()  # Delete previous gradients
            y_hat_tr_batch = model(x_tr_batch)  # Forward pass
            loss = criterion(y_hat_tr_batch, y_tr_batch)  # Compute loss
            loss.backward()  # Backward pass
            opt.step()  # Update weights
            total_train_loss += loss.item()  # Accumulate loss

            if (i + 1) % 10 == 0:
                print(f'Epoch {epoch+1}, Iteration {i+1}, Loss: {loss.item():.6f}')

        avg_train_loss = total_train_loss / len(train_loader)  # Compute average loss
        avg_train_losses.append(avg_train_loss)  # Store average loss

    # Plot training loss
    fig, ax = plt.subplots(figsize=(8, 5))
    ax.plot(range(1, num_epoch + 1), avg_train_losses, label='training loss')
    ax.set_xlabel('epochs')
    ax.set_ylabel('MSE loss')
    ax.set_yscale('log')  # Log scale for better visualization
    ax.set_title('training loss')
    ax.grid(True)
    ax.legend()
    plt.show()

# %% [markdown]
# ___
# ### Now, let us define hyperparameters and train the network.
#
# #### Note, in addition to the parameters that controls the network architecture or the training process, you need to select/initialize (i) a data loader, (ii) a model, (iii) an optimizer, and (iv) a loss function.

# %%
batch_size = 5  # Number of complete images in each batch
lr = 1e-3  # Learning rate
num_epoch = 100  # Epochs

# Model, criterion, and optimizer
train_loader = create_loader(train_dataset, batch_size)
model = UNetSkips(in_channels=1, out_channels=1).to(device) # see if this helps gradient problem from below UNetEnhanced
#model = UNetEnhanced(in_channels=1, out_channels=1).to(device) # test U-Net instead of TrivialNet
#model = UNetSuperRes(in_channels=1, out_channels=1).to(device) # test U-Net instead of TrivialNet
#model = UNet(in_channels=1, out_channels=1).to(device) # test U-Net instead of TrivialNet
#model = TrivialNet().to(device)  # Pick a model and move to GPU/CPU
opt = optim.Adam(model.parameters(), lr=lr)  # Pick an optimizer
criterion = nn.MSELoss()  # Pick a loss function

# Train the model
train_model(model, opt, criterion, train_loader, num_epoch)
# Out:
# Epoch 1, Iteration 10, Loss: 0.006876
# Epoch 1, Iteration 20, Loss: 0.002022
# Epoch 1, Iteration 30, Loss: 0.001841
# Epoch 1, Iteration 40, Loss: 0.005790
# Epoch 2, Iteration 10, Loss: 0.001973
# Epoch 2, Iteration 20, Loss: 0.002629
# Epoch 2, Iteration 30, Loss: 0.001286
# Epoch 2, Iteration 40, Loss: 0.002246
# Epoch 3, Iteration 10, Loss: 0.001488
# Epoch 3, Iteration 20, Loss: 0.001180
# Epoch 3, Iteration 30, Loss: 0.001466
# Epoch 3, Iteration 40, Loss: 0.001079
# Epoch 4, Iteration 10, Loss: 0.002492
# Epoch 4, Iteration 20, Loss: 0.004161
# Epoch 4, Iteration 30, Loss: 0.001025
# Epoch 4, Iteration 40, Loss: 0.001626
# Epoch 5, Iteration 10, Loss: 0.001174
# Epoch 5, Iteration 20, Loss: 0.000936
# Epoch 5, Iteration 30, Loss: 0.001008
# Epoch 5, Iteration 40, Loss: 0.001024
# Epoch 6, Iteration 10, Loss: 0.000893
# Epoch 6, Iteration 20, Loss: 0.001234
# Epoch 6, Iteration 30, Loss: 0.000571
# Epoch 6, Iteration 40, Loss: 0.000908
# Epoch 7, Iteration 10, Loss: 0.000852
# Epoch 7, Iteration 20, Loss: 0.000543
# Epoch 7, Iteration 30, Loss: 0.001071
# Epoch 7, Iteration 40, Loss: 0.000592
# Epoch 8, Iteration 10, Loss: 0.001569
# Epoch 8, Iteration 20, Loss: 0.001243
# Epoch 8, Iteration 30, Loss: 0.000670
# Epoch 8, Iteration 40, Loss: 0.000678
# Epoch 9, Iteration 10, Loss: 0.001882
# Epoch 9, Iteration 20, Loss: 0.000963
# Epoch 9, Iteration 30, Loss: 0.001668
# Epoch 9, Iteration 40, Loss: 0.000680
# Epoch 10, Iteration 10, Loss: 0.000656
# Epoch 10, Iteration 20, Loss: 0.000553
# Epoch 10, Iteration 30, Loss: 0.000515
# Epoch 10, Iteration 40, Loss: 0.001084
# Epoch 11, Iteration 10, Loss: 0.000505
# Epoch 11, Iteration 20, Loss: 0.000693
# Epoch 11, Iteration 30, Loss: 0.000500
# Epoch 11, Iteration 40, Loss: 0.001171
# Epoch 12, Iteration 10, Loss: 0.001413
# Epoch 12, Iteration 20, Loss: 0.001213
# Epoch 12, Iteration 30, Loss: 0.000464
# Epoch 12, Iteration 40, Loss: 0.000569
# Epoch 13, Iteration 10, Loss: 0.001975
# Epoch 13, Iteration 20, Loss: 0.000484
# Epoch 13, Iteration 30, Loss: 0.000486
# Epoch 13, Iteration 40, Loss: 0.000471
# Epoch 14, Iteration 10, Loss: 0.000649
# Epoch 14, Iteration 20, Loss: 0.000852
# Epoch 14, Iteration 30, Loss: 0.000491
# Epoch 14, Iteration 40, Loss: 0.000675
# Epoch 15, Iteration 10, Loss: 0.000669
# Epoch 15, Iteration 20, Loss: 0.001157
# Epoch 15, Iteration 30, Loss: 0.000703
# Epoch 15, Iteration 40, Loss: 0.000521
# Epoch 16, Iteration 10, Loss: 0.000653
# Epoch 16, Iteration 20, Loss: 0.000512
# Epoch 16, Iteration 30, Loss: 0.000718
# Epoch 16, Iteration 40, Loss: 0.000578
# Epoch 17, Iteration 10, Loss: 0.000954
# Epoch 17, Iteration 20, Loss: 0.000742
# Epoch 17, Iteration 30, Loss: 0.000627
# Epoch 17, Iteration 40, Loss: 0.000688
# Epoch 18, Iteration 10, Loss: 0.000638
# Epoch 18, Iteration 20, Loss: 0.001544
# Epoch 18, Iteration 30, Loss: 0.000640
# Epoch 18, Iteration 40, Loss: 0.000412
# Epoch 19, Iteration 10, Loss: 0.000445
# Epoch 19, Iteration 20, Loss: 0.000473
# Epoch 19, Iteration 30, Loss: 0.000823
# Epoch 19, Iteration 40, Loss: 0.001234
# Epoch 20, Iteration 10, Loss: 0.000748
# Epoch 20, Iteration 20, Loss: 0.000408
# Epoch 20, Iteration 30, Loss: 0.000428
# Epoch 20, Iteration 40, Loss: 0.000474
# Epoch 21, Iteration 10, Loss: 0.000769
# Epoch 21, Iteration 20, Loss: 0.000570
# Epoch 21, Iteration 30, Loss: 0.000518
# Epoch 21, Iteration 40, Loss: 0.000594
# Epoch 22, Iteration 10, Loss: 0.000475
# Epoch 22, Iteration 20, Loss: 0.000478
# Epoch 22, Iteration 30, Loss: 0.000644
# Epoch 22, Iteration 40, Loss: 0.000590
# Epoch 23, Iteration 10, Loss: 0.000386
# Epoch 23, Iteration 20, Loss: 0.000511
# Epoch 23, Iteration 30, Loss: 0.000395
# Epoch 23, Iteration 40, Loss: 0.000480
# Epoch 24, Iteration 10, Loss: 0.000627
# Epoch 24, Iteration 20, Loss: 0.000491
# Epoch 24, Iteration 30, Loss: 0.000586
# Epoch 24, Iteration 40, Loss: 0.000509
# Epoch 25, Iteration 10, Loss: 0.000358
# Epoch 25, Iteration 20, Loss: 0.000465
# Epoch 25, Iteration 30, Loss: 0.000854
# Epoch 25, Iteration 40, Loss: 0.000588
# Epoch 26, Iteration 10, Loss: 0.000872
# Epoch 26, Iteration 20, Loss: 0.000814
# Epoch 26, Iteration 30, Loss: 0.000524
# Epoch 26, Iteration 40, Loss: 0.000670
# Epoch 27, Iteration 10, Loss: 0.000425
# Epoch 27, Iteration 20, Loss: 0.000462
# Epoch 27, Iteration 30, Loss: 0.000501
# Epoch 27, Iteration 40, Loss: 0.000768
# Epoch 28, Iteration 10, Loss: 0.000392
# Epoch 28, Iteration 20, Loss: 0.000368
# Epoch 28, Iteration 30, Loss: 0.000888
# Epoch 28, Iteration 40, Loss: 0.000455
# Epoch 29, Iteration 10, Loss: 0.000666
# Epoch 29, Iteration 20, Loss: 0.000433
# Epoch 29, Iteration 30, Loss: 0.000498
# Epoch 29, Iteration 40, Loss: 0.000446
# Epoch 30, Iteration 10, Loss: 0.000381
# Epoch 30, Iteration 20, Loss: 0.000546
# Epoch 30, Iteration 30, Loss: 0.000392
# Epoch 30, Iteration 40, Loss: 0.000588
# Epoch 31, Iteration 10, Loss: 0.000388
# Epoch 31, Iteration 20, Loss: 0.000616
# Epoch 31, Iteration 30, Loss: 0.000664
# Epoch 31, Iteration 40, Loss: 0.000389
# Epoch 32, Iteration 10, Loss: 0.000436
# Epoch 32, Iteration 20, Loss: 0.000656
# Epoch 32, Iteration 30, Loss: 0.000886
# Epoch 32, Iteration 40, Loss: 0.000606
# Epoch 33, Iteration 10, Loss: 0.000453
# Epoch 33, Iteration 20, Loss: 0.000433
# Epoch 33, Iteration 30, Loss: 0.000613
# Epoch 33, Iteration 40, Loss: 0.000384
# Epoch 34, Iteration 10, Loss: 0.000714
# Epoch 34, Iteration 20, Loss: 0.000410
# Epoch 34, Iteration 30, Loss: 0.000340
# Epoch 34, Iteration 40, Loss: 0.000968
# Epoch 35, Iteration 10, Loss: 0.000550
# Epoch 35, Iteration 20, Loss: 0.000384
# Epoch 35, Iteration 30, Loss: 0.000420
# Epoch 35, Iteration 40, Loss: 0.000658
# Epoch 36, Iteration 10, Loss: 0.000454
# Epoch 36, Iteration 20, Loss: 0.000353
# Epoch 36, Iteration 30, Loss: 0.000407
# Epoch 36, Iteration 40, Loss: 0.000400
# Epoch 37, Iteration 10, Loss: 0.000386
# Epoch 37, Iteration 20, Loss: 0.000331
# Epoch 37, Iteration 30, Loss: 0.000580
# Epoch 37, Iteration 40, Loss: 0.000927
# Epoch 38, Iteration 10, Loss: 0.000842
# Epoch 38, Iteration 20, Loss: 0.000663
# Epoch 38, Iteration 30, Loss: 0.000493
# Epoch 38, Iteration 40, Loss: 0.000410
# Epoch 39, Iteration 10, Loss: 0.000360
# Epoch 39, Iteration 20, Loss: 0.000380
# Epoch 39, Iteration 30, Loss: 0.000343
# Epoch 39, Iteration 40, Loss: 0.000419
# Epoch 40, Iteration 10, Loss: 0.000346
# Epoch 40, Iteration 20, Loss: 0.000640
# Epoch 40, Iteration 30, Loss: 0.000494
# Epoch 40, Iteration 40, Loss: 0.000370
# Epoch 41, Iteration 10, Loss: 0.000598
# Epoch 41, Iteration 20, Loss: 0.000358
# Epoch 41, Iteration 30, Loss: 0.000407
# Epoch 41, Iteration 40, Loss: 0.000390
# Epoch 42, Iteration 10, Loss: 0.000458
# Epoch 42, Iteration 20, Loss: 0.000413
# Epoch 42, Iteration 30, Loss: 0.000497
# Epoch 42, Iteration 40, Loss: 0.000326
# Epoch 43, Iteration 10, Loss: 0.000403
# Epoch 43, Iteration 20, Loss: 0.000343
# Epoch 43, Iteration 30, Loss: 0.000365
# Epoch 43, Iteration 40, Loss: 0.000634
# Epoch 44, Iteration 10, Loss: 0.000480
# Epoch 44, Iteration 20, Loss: 0.000403
# Epoch 44, Iteration 30, Loss: 0.000500
# Epoch 44, Iteration 40, Loss: 0.000246
# Epoch 45, Iteration 10, Loss: 0.000593
# Epoch 45, Iteration 20, Loss: 0.000523
# Epoch 45, Iteration 30, Loss: 0.000347
# Epoch 45, Iteration 40, Loss: 0.000325
# Epoch 46, Iteration 10, Loss: 0.000459
# Epoch 46, Iteration 20, Loss: 0.000427
# Epoch 46, Iteration 30, Loss: 0.000384
# Epoch 46, Iteration 40, Loss: 0.000421
# Epoch 47, Iteration 10, Loss: 0.000324
# Epoch 47, Iteration 20, Loss: 0.000359
# Epoch 47, Iteration 30, Loss: 0.000327
# Epoch 47, Iteration 40, Loss: 0.000473
# Epoch 48, Iteration 10, Loss: 0.000428
# Epoch 48, Iteration 20, Loss: 0.000337
# Epoch 48, Iteration 30, Loss: 0.000389
# Epoch 48, Iteration 40, Loss: 0.000403
# Epoch 49, Iteration 10, Loss: 0.000440
# Epoch 49, Iteration 20, Loss: 0.000366
# Epoch 49, Iteration 30, Loss: 0.000481
# Epoch 49, Iteration 40, Loss: 0.001256
# Epoch 50, Iteration 10, Loss: 0.000842
# Epoch 50, Iteration 20, Loss: 0.000477
# Epoch 50, Iteration 30, Loss: 0.000670
# Epoch 50, Iteration 40, Loss: 0.000469
# Epoch 51, Iteration 10, Loss: 0.000422
# Epoch 51, Iteration 20, Loss: 0.000299
# Epoch 51, Iteration 30, Loss: 0.000569
# Epoch 51, Iteration 40, Loss: 0.000347
# Epoch 52, Iteration 10, Loss: 0.000393
# Epoch 52, Iteration 20, Loss: 0.000324
# Epoch 52, Iteration 30, Loss: 0.000295
# Epoch 52, Iteration 40, Loss: 0.000379
# Epoch 53, Iteration 10, Loss: 0.000360
# Epoch 53, Iteration 20, Loss: 0.000481
# Epoch 53, Iteration 30, Loss: 0.000340
# Epoch 53, Iteration 40, Loss: 0.000323
# Epoch 54, Iteration 10, Loss: 0.000327
# Epoch 54, Iteration 20, Loss: 0.000470
# Epoch 54, Iteration 30, Loss: 0.000726
# Epoch 54, Iteration 40, Loss: 0.000427
# Epoch 55, Iteration 10, Loss: 0.000348
# Epoch 55, Iteration 20, Loss: 0.000344
# Epoch 55, Iteration 30, Loss: 0.000396
# Epoch 55, Iteration 40, Loss: 0.000377
# Epoch 56, Iteration 10, Loss: 0.000400
# Epoch 56, Iteration 20, Loss: 0.000363
# Epoch 56, Iteration 30, Loss: 0.000332
# Epoch 56, Iteration 40, Loss: 0.000305
# Epoch 57, Iteration 10, Loss: 0.000399
# Epoch 57, Iteration 20, Loss: 0.000532
# Epoch 57, Iteration 30, Loss: 0.000388
# Epoch 57, Iteration 40, Loss: 0.000325
# Epoch 58, Iteration 10, Loss: 0.000583
# Epoch 58, Iteration 20, Loss: 0.000339
# Epoch 58, Iteration 30, Loss: 0.000661
# Epoch 58, Iteration 40, Loss: 0.000368
# Epoch 59, Iteration 10, Loss: 0.000638
# Epoch 59, Iteration 20, Loss: 0.001104
# Epoch 59, Iteration 30, Loss: 0.000411
# Epoch 59, Iteration 40, Loss: 0.000421
# Epoch 60, Iteration 10, Loss: 0.000522
# Epoch 60, Iteration 20, Loss: 0.000333
# Epoch 60, Iteration 30, Loss: 0.000306
# Epoch 60, Iteration 40, Loss: 0.000282
# Epoch 61, Iteration 10, Loss: 0.000337
# Epoch 61, Iteration 20, Loss: 0.000365
# Epoch 61, Iteration 30, Loss: 0.000354
# Epoch 61, Iteration 40, Loss: 0.000282
# Epoch 62, Iteration 10, Loss: 0.000382
# Epoch 62, Iteration 20, Loss: 0.000348
# Epoch 62, Iteration 30, Loss: 0.000360
# Epoch 62, Iteration 40, Loss: 0.000352
# Epoch 63, Iteration 10, Loss: 0.000356
# Epoch 63, Iteration 20, Loss: 0.000286
# Epoch 63, Iteration 30, Loss: 0.000801
# Epoch 63, Iteration 40, Loss: 0.000378
# Epoch 64, Iteration 10, Loss: 0.000375
# Epoch 64, Iteration 20, Loss: 0.000336
# Epoch 64, Iteration 30, Loss: 0.000331
# Epoch 64, Iteration 40, Loss: 0.000517
# Epoch 65, Iteration 10, Loss: 0.000304
# Epoch 65, Iteration 20, Loss: 0.000335
# Epoch 65, Iteration 30, Loss: 0.000337
# Epoch 65, Iteration 40, Loss: 0.000519
# Epoch 66, Iteration 10, Loss: 0.000318
# Epoch 66, Iteration 20, Loss: 0.000333
# Epoch 66, Iteration 30, Loss: 0.000352
# Epoch 66, Iteration 40, Loss: 0.000290
# Epoch 67, Iteration 10, Loss: 0.000381
# Epoch 67, Iteration 20, Loss: 0.000375
# Epoch 67, Iteration 30, Loss: 0.000352
# Epoch 67, Iteration 40, Loss: 0.000282
# Epoch 68, Iteration 10, Loss: 0.000324
# Epoch 68, Iteration 20, Loss: 0.000279
# Epoch 68, Iteration 30, Loss: 0.000426
# Epoch 68, Iteration 40, Loss: 0.000300
# Epoch 69, Iteration 10, Loss: 0.000417
# Epoch 69, Iteration 20, Loss: 0.000344
# Epoch 69, Iteration 30, Loss: 0.000325
# Epoch 69, Iteration 40, Loss: 0.000362
# Epoch 70, Iteration 10, Loss: 0.000357
# Epoch 70, Iteration 20, Loss: 0.000297
# Epoch 70, Iteration 30, Loss: 0.000377
# Epoch 70, Iteration 40, Loss: 0.000363
# Epoch 71, Iteration 10, Loss: 0.000363
# Epoch 71, Iteration 20, Loss: 0.000531
# Epoch 71, Iteration 30, Loss: 0.000274
# Epoch 71, Iteration 40, Loss: 0.000365
# Epoch 72, Iteration 10, Loss: 0.000371
# Epoch 72, Iteration 20, Loss: 0.000254
# Epoch 72, Iteration 30, Loss: 0.000296
# Epoch 72, Iteration 40, Loss: 0.000369
# Epoch 73, Iteration 10, Loss: 0.000306
# Epoch 73, Iteration 20, Loss: 0.000443
# Epoch 73, Iteration 30, Loss: 0.000364
# Epoch 73, Iteration 40, Loss: 0.000341
# Epoch 74, Iteration 10, Loss: 0.000331
# Epoch 74, Iteration 20, Loss: 0.000487
# Epoch 74, Iteration 30, Loss: 0.000294
# Epoch 74, Iteration 40, Loss: 0.000373
# Epoch 75, Iteration 10, Loss: 0.000478
# Epoch 75, Iteration 20, Loss: 0.000381
# Epoch 75, Iteration 30, Loss: 0.000349
# Epoch 75, Iteration 40, Loss: 0.000376
# Epoch 76, Iteration 10, Loss: 0.000372
# Epoch 76, Iteration 20, Loss: 0.000268
# Epoch 76, Iteration 30, Loss: 0.000452
# Epoch 76, Iteration 40, Loss: 0.000407
# Epoch 77, Iteration 10, Loss: 0.000303
# Epoch 77, Iteration 20, Loss: 0.000382
# Epoch 77, Iteration 30, Loss: 0.000428
# Epoch 77, Iteration 40, Loss: 0.000264
# Epoch 78, Iteration 10, Loss: 0.000323
# Epoch 78, Iteration 20, Loss: 0.000359
# Epoch 78, Iteration 30, Loss: 0.000448
# Epoch 78, Iteration 40, Loss: 0.000414
# Epoch 79, Iteration 10, Loss: 0.000304
# Epoch 79, Iteration 20, Loss: 0.000251
# Epoch 79, Iteration 30, Loss: 0.000266
# Epoch 79, Iteration 40, Loss: 0.000310
# Epoch 80, Iteration 10, Loss: 0.000344
# Epoch 80, Iteration 20, Loss: 0.000373
# Epoch 80, Iteration 30, Loss: 0.000258
# Epoch 80, Iteration 40, Loss: 0.000309
# Epoch 81, Iteration 10, Loss: 0.000480
# Epoch 81, Iteration 20, Loss: 0.000302
# Epoch 81, Iteration 30, Loss: 0.000250
# Epoch 81, Iteration 40, Loss: 0.000345
# Epoch 82, Iteration 10, Loss: 0.000377
# Epoch 82, Iteration 20, Loss: 0.000374
# Epoch 82, Iteration 30, Loss: 0.000284
# Epoch 82, Iteration 40, Loss: 0.000410
# Epoch 83, Iteration 10, Loss: 0.000379
# Epoch 83, Iteration 20, Loss: 0.000404
# Epoch 83, Iteration 30, Loss: 0.000336
# Epoch 83, Iteration 40, Loss: 0.000475
# Epoch 84, Iteration 10, Loss: 0.000305
# Epoch 84, Iteration 20, Loss: 0.000302
# Epoch 84, Iteration 30, Loss: 0.000356
# Epoch 84, Iteration 40, Loss: 0.000236
# Epoch 85, Iteration 10, Loss: 0.000285
# Epoch 85, Iteration 20, Loss: 0.000351
# Epoch 85, Iteration 30, Loss: 0.000348
# Epoch 85, Iteration 40, Loss: 0.000408
# Epoch 86, Iteration 10, Loss: 0.000335
# Epoch 86, Iteration 20, Loss: 0.000313
# Epoch 86, Iteration 30, Loss: 0.000392
# Epoch 86, Iteration 40, Loss: 0.000315
# Epoch 87, Iteration 10, Loss: 0.000367
# Epoch 87, Iteration 20, Loss: 0.000305
# Epoch 87, Iteration 30, Loss: 0.000375
# Epoch 87, Iteration 40, Loss: 0.000363
# Epoch 88, Iteration 10, Loss: 0.000413
# Epoch 88, Iteration 20, Loss: 0.000331
# Epoch 88, Iteration 30, Loss: 0.000357
# Epoch 88, Iteration 40, Loss: 0.000283
# Epoch 89, Iteration 10, Loss: 0.000549
# Epoch 89, Iteration 20, Loss: 0.000603
# Epoch 89, Iteration 30, Loss: 0.000531
# Epoch 89, Iteration 40, Loss: 0.000680
# Epoch 90, Iteration 10, Loss: 0.000471
# Epoch 90, Iteration 20, Loss: 0.000421
# Epoch 90, Iteration 30, Loss: 0.000315
# Epoch 90, Iteration 40, Loss: 0.000393
# Epoch 91, Iteration 10, Loss: 0.000356
# Epoch 91, Iteration 20, Loss: 0.000559
# Epoch 91, Iteration 30, Loss: 0.000336
# Epoch 91, Iteration 40, Loss: 0.000933
# Epoch 92, Iteration 10, Loss: 0.000511
# Epoch 92, Iteration 20, Loss: 0.000562
# Epoch 92, Iteration 30, Loss: 0.000779
# Epoch 92, Iteration 40, Loss: 0.000301
# Epoch 93, Iteration 10, Loss: 0.000261
# Epoch 93, Iteration 20, Loss: 0.000322
# Epoch 93, Iteration 30, Loss: 0.000649
# Epoch 93, Iteration 40, Loss: 0.000431
# Epoch 94, Iteration 10, Loss: 0.000401
# Epoch 94, Iteration 20, Loss: 0.000295
# Epoch 94, Iteration 30, Loss: 0.000696
# Epoch 94, Iteration 40, Loss: 0.000378
# Epoch 95, Iteration 10, Loss: 0.000266
# Epoch 95, Iteration 20, Loss: 0.000261
# Epoch 95, Iteration 30, Loss: 0.000359
# Epoch 95, Iteration 40, Loss: 0.000331
# Epoch 96, Iteration 10, Loss: 0.000283
# Epoch 96, Iteration 20, Loss: 0.000325
# Epoch 96, Iteration 30, Loss: 0.000315
# Epoch 96, Iteration 40, Loss: 0.000465
# Epoch 97, Iteration 10, Loss: 0.000264
# Epoch 97, Iteration 20, Loss: 0.000307
# Epoch 97, Iteration 30, Loss: 0.000435
# Epoch 97, Iteration 40, Loss: 0.000361
# Epoch 98, Iteration 10, Loss: 0.000255
# Epoch 98, Iteration 20, Loss: 0.000293
# Epoch 98, Iteration 30, Loss: 0.000374
# Epoch 98, Iteration 40, Loss: 0.000331
# Epoch 99, Iteration 10, Loss: 0.000276
# Epoch 99, Iteration 20, Loss: 0.000288
# Epoch 99, Iteration 30, Loss: 0.000315
# Epoch 99, Iteration 40, Loss: 0.000480
# Epoch 100, Iteration 10, Loss: 0.000308
# Epoch 100, Iteration 20, Loss: 0.000305
# Epoch 100, Iteration 30, Loss: 0.000243
# Epoch 100, Iteration 40, Loss: 0.000500

# %% [markdown]
# ___
# ### Apply it one of the validation image

# %%
# Create the dataset for validation images
val_dataset = TIFFDataset('data/val/high-res', 'data/val/low-res', transform=transform)

# Load one (low-res, high-res) image pair from validation dataset and move it to the dedvice
val_low_res, val_high_res = val_dataset[1]  # Input (128x128), Ground truth (256x256)
val_low_res, val_high_res = val_low_res.to(device), val_high_res.to(device)

# Upsample low-resolution image to 256x256 for both model input and error visualization
val_low_res_interpolated = torch.nn.functional.interpolate(val_low_res.unsqueeze(0), scale_factor=2, mode='bicubic', align_corners=False).squeeze(0)

# Apply the trained model to super-resolve the interpolated low-res image
val_super_res = model(val_low_res_interpolated.unsqueeze(0)).detach().squeeze(0)  # Remove batch dimension

# Convert tensors to numpy for visualization
val_low_res_np = val_low_res_interpolated.squeeze().cpu().numpy()  # Use the interpolated version for error maps
val_high_res_np = val_high_res.squeeze().cpu().numpy()
val_super_res_np = val_super_res.squeeze().cpu().numpy()

# Plot an example image and error maps
fig, ax = plt.subplots(2, 3, figsize=(10, 7))

# Plot images
ax[0, 0].imshow(val_high_res_np, cmap='gray', vmin=0, vmax=1)
ax[0, 0].set_title('ground truth (high-res)')
ax[0, 0].axis('off')

ax[0, 1].imshow(val_low_res_np, cmap='gray', vmin=0, vmax=1)
ax[0, 1].set_title('interpolated low-res image')
ax[0, 1].axis('off')

ax[0, 2].imshow(val_super_res_np, cmap='gray', vmin=0, vmax=1)
ax[0, 2].set_title('super-resolved image')
ax[0, 2].axis('off')

# Error maps
ax[1, 0].imshow(5 * np.abs(val_high_res_np - val_high_res_np), cmap='gray', vmin=0, vmax=1)
ax[1, 0].axis('off')
ax[1, 0].text(0.02, 0.98, r'$\times 5$', transform=ax[1, 0].transAxes, fontsize=14, va='top', ha='left', color='white')

ax[1, 1].imshow(5 * np.abs(val_high_res_np - val_low_res_np), cmap='gray', vmin=0, vmax=1)
ax[1, 1].axis('off')
ax[1, 1].text(0.02, 0.98, r'$\times 5$', transform=ax[1, 1].transAxes, fontsize=14, va='top', ha='left', color='white')

ax[1, 2].imshow(5 * np.abs(val_high_res_np - val_super_res_np), cmap='gray', vmin=0, vmax=1)
ax[1, 2].axis('off')
ax[1, 2].text(0.02, 0.98, r'$\times 5$', transform=ax[1, 2].transAxes, fontsize=14, va='top', ha='left', color='white')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Compute PSNR and SSIM over the entire validation dataset

# %%
# Initialize metrics
psnr_metric = PeakSignalNoiseRatio().to(device) # rewrite
ssim_metric = StructuralSimilarityIndexMeasure(data_range=1.0).to(device)

# Accumulators
total_psnr_interpolated = 0
total_psnr_super_resolved = 0
total_ssim_interpolated = 0
total_ssim_super_resolved = 0
num_samples = len(val_dataset)

# Loop over validation set
for i in range(num_samples):
    val_low_res, val_high_res = val_dataset[i]
    val_low_res, val_high_res = val_low_res.to(device), val_high_res.to(device)

    # Compute data range dynamically
    data_range = val_high_res.max() - val_high_res.min()
    ssim_metric.data_range = data_range

    # Upsample low-res image
    val_low_res_up = torch.nn.functional.interpolate(val_low_res.unsqueeze(0), scale_factor=2, mode='bicubic', align_corners=False)
    val_high_res = val_high_res.unsqueeze(0)  # Add batch dim
    val_super_res = model(val_low_res_up).detach()

    # PSNR
    psnr_interp = psnr_metric(val_low_res_up, val_high_res).item()
    psnr_sr = psnr_metric(val_super_res, val_high_res).item()

    # SSIM (data_range is now set in metric initialization)
    ssim_interp = ssim_metric(val_low_res_up, val_high_res).item()
    ssim_sr = ssim_metric(val_super_res, val_high_res).item()

    # Accumulate
    total_psnr_interpolated += psnr_interp
    total_psnr_super_resolved += psnr_sr
    total_ssim_interpolated += ssim_interp
    total_ssim_super_resolved += ssim_sr

# Averages
avg_psnr_interp = total_psnr_interpolated / num_samples
avg_psnr_sr = total_psnr_super_resolved / num_samples
avg_ssim_interp = total_ssim_interpolated / num_samples
avg_ssim_sr = total_ssim_super_resolved / num_samples

# Print results
print(f'Average PSNR (interpolated): {avg_psnr_interp:.2f} dB')
print(f'Average PSNR (super-resolved): {avg_psnr_sr:.2f} dB')
print(f'Average SSIM (interpolated): {avg_ssim_interp:.4f}')
print(f'Average SSIM (super-resolved): {avg_ssim_sr:.4f}')
print(avg_psnr_sr+40*avg_ssim_sr)
#print(f'Average SSIM (super-resolved): {avg_ssim_sr:.4f}')
# Out:
# Average PSNR (interpolated): 30.81 dB
# Average PSNR (super-resolved): 32.47 dB
# Average SSIM (interpolated): 0.9056
# Average SSIM (super-resolved): 0.8487
# 66.42046454747518
